# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "6"

import torch

print(torch.cuda.get_device_name())

import functools
import ipywidgets

import re

import numpy as np
import chardet
import pandas as pd
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', 10000)
import random

import pickle
import spacy

from datasets import load_dataset

from sklearn.utils import shuffle

# Create a spacy natural-language processor for English
nlp = spacy.load("en_core_web_sm")

# build the vocabulary for the tf-idf
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

from faiss import IndexFlatL2, read_index, write_index
# Out:
# NVIDIA A100 80GB PCIe

# %% [markdown]
# # DATA AND SUPPORT FUNCTIONS

# %%
#NEWS_PATH = "/data01/atrema/20newsgroups/"
#bad_lines = ["From:", "writes:", "wrote:",'.edu', '@', '.gov', 'Subject:']
bad_lines = ['"']
TOPICS = ["talk.politics.misc","sci.med","soc.religion.christian"]
DATASET_LINK = "sentence-transformers/wikipedia-en-sentences"#"Fraser/wiki_sentences"#

# %%
def prep_wiki(DATASET_LINK, size):
    data = load_dataset(DATASET_LINK, split='train')
    df = pd.DataFrame({'text' : data['sentence']})[:10**6]
    print('total size : ', len(df))    
    df.text = df.text.apply(lambda x : re.sub(r"\(.*?\)", "", x))
    df.text = df.text.apply(lambda x : rm_special_chars(x))
    df = df[(df.text.str.len() >= 50) & (df.text.str.len() <= 500)]
    print('length range size : ', len(df))

    #for training
    tmp = df[:size] #df.sample(n= size, random_state=88)
    tmp = shuffle(tmp)
    train_collection = tmp.sample(frac=0.8, random_state=99)
    train_set = tmp.drop(train_collection.index)

    #for testing
    gap = 10**5
    tmp = df[gap : gap + size]
    tmp = shuffle(tmp)
    test_collection = tmp.sample(frac=0.8, random_state=99)
    test_set = tmp.drop(test_collection.index)

    #for line in bad_lines:
    #    tmp_1 = df[df['text'].str.contains(line)].index.tolist()
    #    df = df.drop(tmp_1) 
    
    print(f'Train Collection size : {len(train_collection)}')
    print(f'Trainset size : {len(train_set)}')
    print(f'Test Collection size : {len(test_collection)}')
    print(f'Testset size : {len(test_set)}')
    
    return train_collection, train_set, test_collection, test_set


def prep_news(news_types):
    for news_type in news_types:
        with open(NEWS_PATH + news_type + ".txt", 'rb') as f:
            result = chardet.detect(f.read())
            #print(result)
        encoding = result['encoding']
        tmp = pd.read_csv(NEWS_PATH + news_type + ".txt", encoding=encoding, on_bad_lines='skip')
        #topic = tmp.columns[0].strip('Newsgroup:')
        tmp['topic'] = news_type
        tmp =tmp.rename(columns={f'{tmp.columns[0]}' : 'text'})
        #df = df.drop_duplicates(subset=[df.columns.tolist()[0]], keep='first')
        for line in bad_lines:
            tmp_1 = tmp[tmp['text'].str.contains(line)].index.tolist()
            tmp = tmp.drop(tmp_1)
        tmp['text'] = tmp['text'].apply(lambda x : re.sub(r'n[\'|’]t', ' not', x))
        tmp['text'] = tmp['text'].apply(lambda x : rm_special_chars(x))
        #empties = df[df.text == '']
        #print(empties)
        #df = df.drop(empties.index)
        tmp = tmp[tmp['text'].str.len() >= 40]
        tmp = tmp.drop_duplicates(subset=["text"], keep='first')
        tmp_1 = tmp.sample(frac=0.5, random_state=99) # half for collection, half for train-test
        if news_type == news_types[0]:
            collection = tmp.drop(tmp_1.index)
            train = tmp_1.sample(frac=0.8, random_state=88)
            test = tmp_1.drop(train.index)
        else:
            collection_tmp = tmp.drop(tmp_1.index)
            train_tmp =  tmp_1.sample(frac=0.8, random_state=88)
            test_tmp = tmp_1.drop(train_tmp.index)
            collection = pd.concat([collection, collection_tmp])
            train = pd.concat([train, train_tmp])
            test = pd.concat([test, test_tmp])

    train = train.reset_index(drop=True)
    collection = collection['text'].tolist()
    
    print(f"Topics : {train.topic.unique()}")
    print(f'Collection size : {len(collection)}')
    print(f'Trainset size : {len(train)}')
    print(f'Testset size : {len(test)}')
    return collection, train, test

def mask_word(s):
    text = s['text']
    #print(text)
    tmp = text.split(' ')
    tmp = pd.Series(tmp) # this way each word is associated to an index
    possibilities = tmp[tmp.str.len() >= 3] # only choose mask if the word is at least 3 chars long
    #print(possibilities)
    if possibilities.empty :
        s['groundTruth'] = 'DELETE'
        s['text'] = 'DELETE'
        return s
    ind = random.choice(possibilities.index.tolist()) # choose the index
    s['groundTruth'] = tmp.iloc[ind].lower() # save the ground truth
    mask_length = len(tmp.iloc[ind]) 
    tmp.iloc[ind] = '?' * mask_length # f'[[{mask_length} missing characters]]'# mask the word
    s['text'] = (' ').join(tmp)
    return s

def masking(df):
    df = df.apply(mask_word, axis=1)
    df = df.drop(df[df.text == 'DELETE'].index)
    df = df.reset_index(drop=True)
    #print(f'Masked Testset size : {len(df)}')
    return df

def ft_context(s):
    text = s['text']
    tmp = text.split(' ')
    missing_word_index = tmp.index([s for s in tmp if '?' in s][0]) # get the index of the missing word
    tmp[missing_word_index] = "[MASK]"
    mask_sent = (' ').join(tmp)
    s['context'] = search_lm(mask_sent, top_k=3)
    return s

def contexting(df):
    df = df.apply(ft_context, axis=1)
    return df

# %%
# remove special characters
def rm_special_chars(s):
    #stripped = re.sub(r'[^\w\s]', ' ', s)
    stripped = re.sub(r'[^A-Za-z0-9 ]+', ' ', s)
    stripped = re.sub(' br ', ' ', stripped)
    stripped = re.sub(' +', ' ', stripped)
    stripped = stripped.strip()
    return stripped
# remove first word, split each entry into single sentences, remove special characters
def prep_context(c):
    out=[]
    for i in c:
        #i = rm_first_word(i)
        #tmp = [rm_special_chars(element).lower() for element in i.split('.') if element]
        tmp = [element for element in i.split('.') if element]
        out.extend(tmp)
    return out

# Create our list of punctuation marks
punctuations = string.punctuation
# Create our list of stopwords
nlp = spacy.load('en_core_web_sm')
stop_words = spacy.lang.en.stop_words.STOP_WORDS
# Load English tokenizer, tagger, parser, NER and word vectors
parser = English()

# Creating tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    sentence = rm_special_chars(sentence)
    mytokens = nlp(sentence)
    # Lemmatizing each token and converting each token into lowercase
    mytokens = [word.lemma_.lower() for word in mytokens ]
    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
def tf_idify(context):
    vectorizer = TfidfVectorizer(tokenizer= spacy_tokenizer, token_pattern=None)
    matrix = vectorizer.fit_transform(context)
    words = vectorizer.get_feature_names_out()
    #print("Matrix completed")
    doc_vectors = matrix.toarray()
    dimension = doc_vectors.shape[1]
    index = IndexFlatL2(dimension)
    index.add(doc_vectors)
    return matrix, vectorizer, words, index

def search_tfidf(query, vectorizer, index, documents, top_k):
    query_vector = vectorizer.transform([query]).toarray()
    distances, indices = index.search(query_vector, top_k)
    #print(indices)
    #results = [(news_list[i], distances[0][i]) for i in indices[0]]
    results = [documents[i] for i in indices[0]]
    return results

retriever = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

def LM_retriever(documents):
    embeddings = retriever.encode(documents)
    embeddings_dimension = embeddings.shape[1]
    index = IndexFlatL2(embeddings_dimension)
    index.add(embeddings)
    return index

def search_lm(query, top_k):
    query_embedding = retriever.encode([query], show_progress_bar = False)
    distances, indices = lm_index.search(query_embedding, top_k)
    results = [collection[idx] for idx in indices[0]]
    return results

# %%
#from datasets import load_dataset, Subset

#ds = load_dataset("jordiclive/wikipedia-summary-dataset", split='train', streaming=True)

# %% [markdown]
# ## CORRECT MISTAKES
# Preprocess the data, then correct it with pretrained Llama

# %%
#collection, train_set, test_set = prep_news(TOPICS)
#col1, train1, test1 = prep_news(TOPICS)
# Out:
# Topics : ['talk.politics.misc' 'sci.med' 'soc.religion.christian']
# Collection size : 16933
# Trainset size : 13547
# Testset size : 3387

# %%
#from spellchecker import SpellChecker
#spell = SpellChecker()
#train2 = train1[500:520].copy()
#train2['fixed'] = train2.text.progress_apply(spell.correction)

# %%
from vllm import LLM, SamplingParams
from transformers import AutoTokenizer
# Load the LLama 3 8B model
BASE_MODEL = "meta-llama/Meta-Llama-3-8B-Instruct" 

model = LLM(BASE_MODEL)
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
# Out:
# WARNING 12-13 07:57:00 cuda.py:69] Detected different devices in the system:
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA L40S
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA L40S
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA L40S
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA L40S
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA A100 80GB PCIe
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA L40S
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA A100 80GB PCIe
# WARNING 12-13 07:57:00 cuda.py:69] NVIDIA A100 80GB PCIe
# WARNING 12-13 07:57:00 cuda.py:69] Please make sure to set `CUDA_DEVICE_ORDER=PCI_BUS_ID` to avoid unexpected behavior.
# INFO 12-13 07:57:02 llm_engine.py:226] Initializing an LLM engine (v0.6.1.dev238+ge2c6e0a82) with config: model='meta-llama/Meta-Llama-3-8B-Instruct', speculative_config=None, tokenizer='meta-llama/Meta-Llama-3-8B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=meta-llama/Meta-Llama-3-8B-Instruct, use_v2_block_manager=False, num_scheduler_steps=1, multi_step_stream_outputs=False, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, mm_processor_kwargs=None)
# INFO 12-13 07:57:02 model_runner.py:1014] Starting to load model meta-llama/Meta-Llama-3-8B-Instruct...
# INFO 12-13 07:57:03 weight_utils.py:242] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# INFO 12-13 07:57:05 model_runner.py:1025] Loading model weights took 14.9595 GB
# INFO 12-13 07:57:07 gpu_executor.py:122] # GPU blocks: 11991, # CPU blocks: 2048
# INFO 12-13 07:57:08 model_runner.py:1329] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 12-13 07:57:08 model_runner.py:1333] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 12-13 07:57:24 model_runner.py:1456] Graph capturing finished in 16 secs.

# %%
correct_system = """
                You are an automated English spelling check machine.
                Correct any spelling mistakes in the sentence that you are given, and just return the corrected sentence, without any introduction.
                If you find no mistakes, simply return the sentence as it is.
                Use {$examples} to better understand the task.
               """
correct_examples =  """
        These are the examples that you can use to understand how to solve the task :
        
        -Example 1: INPUT= I wishe I was en Dixie. OUTPUT=I wish I was in Dixie. ;
        -Example 2: INPUT= Maybe you coud try to act nycely OUTPUT= Maybe you could try to act nicely ;
        -Example 3: INPUT= The ents justyfy the meens. OUTPUT= The ends justify the means.
            """
CORRECT_PARAMS = SamplingParams(n=1, max_tokens=300)
def correct(s):
    sent = s['text']
    messages = [
                {'role' : 'system', 'content' : correct_system},
                {'role' : 'examples', 'content' : correct_examples},
                {'role' : 'problem', 'content' : sent}
            ]
    formatted_prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True,)
    output = model.generate(formatted_prompt, sampling_params=CORRECT_PARAMS, use_tqdm=False)
    out = output[0].outputs
    s['text'] = out[0].text
    return s

# %%
from tqdm import tqdm
tqdm.pandas(leave=None)

# %%
train_set = train_set.progress_apply(correct, axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13547/13547 [1:17:56<00:00,  2.90it/s]

# %%
test_set = test_set.progress_apply(correct, axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3387/3387 [19:21<00:00,  2.92it/s]

# %%
df_collection = pd.DataFrame({'text' : collection})
df_collection = df_collection.progress_apply(correct, axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16933/16933 [1:37:13<00:00,  2.90it/s]

# %%
#clean collection
to_del = df_collection[df_collection.text.str.contains("s the corrected sentence:")]
df_collection = df_collection.drop(to_del.index)
to_del = df_collection[df_collection.text.str.contains("I cannot correct")]
df_collection = df_collection.drop(to_del.index)
to_del = df_collection[df_collection.text.str.contains("I can't correct")]
df_collection = df_collection.drop(to_del.index)

df_collection.text = df_collection.text.apply(lambda x : rm_special_chars(x))

#clean train_set
to_del = train_set[train_set.text.str.contains("s the corrected sentence:")]
train_set = train_set.drop(to_del.index)
to_del = train_set[train_set.text.str.contains("I cannot correct")]
train_set = train_set.drop(to_del.index)
to_del = train_set[train_set.text.str.contains("I can't correct")]
train_set = train_set.drop(to_del.index)

train_set.text = train_set.text.apply(lambda x : rm_special_chars(x))

#clean test_set
to_del = test_set[test_set.text.str.contains("s the corrected sentence:")]
test_set = test_set.drop(to_del.index)
to_del = test_set[test_set.text.str.contains("I cannot correct")]
test_set = test_set.drop(to_del.index)
to_del = test_set[test_set.text.str.contains("I can't correct")]
test_set = test_set.drop(to_del.index)

test_set.text = test_set.text.apply(lambda x : rm_special_chars(x))

# %% [markdown]
# ## SAVE DATA

# %%
train_collection, train_set, test_collection, test_set = prep_wiki(DATASET_LINK, 20000)
# Out:
# Using the latest cached version of the dataset since sentence-transformers/wikipedia-en-sentences couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/atrema/.cache/huggingface/datasets/sentence-transformers___wikipedia-en-sentences/default/0.0.0/4a0972dcb781b5b5d27799798f032606421dd422 (last modified on Mon Dec 16 08:51:10 2024).
# total size :  1000000
# length range size :  916404
# Train Collection size : 16000
# Trainset size : 4000
# Test Collection size : 16000
# Testset size : 4000

# %% [markdown]
# ### Training

# %%
train_collection_list = train_collection.text.tolist()

# %%
#create the index with ST embeddings
train_index = LM_retriever(train_collection_list)
write_index(train_index, 'saved_files/train_data/train_index')

# %%
with open('saved_files/train_data/train_collection.pickle', 'wb') as f:
    pickle.dump(train_collection_list, f)

train_set.to_csv('saved_files/train_data/train_set_unmasked', index=False)
masked_train = masking(train_set)
masked_train.to_csv('saved_files/train_data/train_set', index=False)

# %% [markdown]
# ### Testing

# %%
test_collection_list = test_collection.text.tolist()

# %%
# get the tf-idf matrix, the vectorizer, the set of words in it , for TFIDFRAG
matrix_3, vectorizer_3, words_3, index_3 = tf_idify(test_collection_list)
#create the index with ST embeddings
test_index = LM_retriever(test_collection_list)

# %%
write_index(test_index, 'saved_files/test_data/test_index')
write_index(index_3, 'saved_files/test_data/tfidf_index')
with open('saved_files/test_data/vectorizer', 'wb') as f:
    pickle.dump(vectorizer_3, f)
with open('saved_files/test_data/matrix', 'wb') as f:
    pickle.dump(matrix_3, f)

# %%
with open('saved_files/test_data/test_collection.pickle', 'wb') as f:
    pickle.dump(test_collection_list, f)
 
test_set.to_csv('saved_files/test_data/test_set_unmasked', index=False)
masked_test = masking(test_set)
masked_test.to_csv('saved_files/test_data/test_set', index=False)

# %% [markdown]
# # FINE TUNING

# %%
#unless you want an OUT OF MEMORY Error
del model
del tokenizer

# %%
from unsloth import FastLanguageModel, is_bfloat16_supported
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# ## PREPARE DATA
# For RAG model

# %%
train_set = pd.read_csv('saved_files/train_data/train_set')
lm_index = read_index('saved_files/train_data/train_index')
with open('saved_files/train_data/train_collection.pickle', 'rb') as f:
    collection = pickle.load(f)

# %%
#train_set_cont = contexting(train_set)
#train_set_cont.to_csv('saved_files/train_data/train_set_context', index=False)
model_folder = "outputs/ragged_model"
train_set = pd.read_csv('saved_files/train_data/train_set_context')

# %% [markdown]
# For no-RAG model

# %%
model_folder = "outputs/unragged_model"
train_set = pd.read_csv('saved_files/train_data/train_set')

# %% [markdown]
# ## FINE-TUNE

# %%
# Check CUDA compatibility
major_version, minor_version = torch.cuda.get_device_capability()

# Instantiate FastLanguageModel
max_seq_length = 2048
dtype = None
load_in_4bit = True

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="meta-llama/Meta-Llama-3-8B-Instruct",
    max_seq_length=4096,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.8: Fast Llama patching. Transformers = 4.46.3.
#    \\   /|    GPU: NVIDIA A100 80GB PCIe. Max memory: 79.151 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.4.0+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.27.post2. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# <string>:204: SyntaxWarning: invalid escape sequence '\ '
# <string>:205: SyntaxWarning: invalid escape sequence '\_'
# <string>:206: SyntaxWarning: invalid escape sequence '\ '
# <string>:204: SyntaxWarning: invalid escape sequence '\ '
# <string>:205: SyntaxWarning: invalid escape sequence '\_'
# <string>:206: SyntaxWarning: invalid escape sequence '\ '

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing=True,
    random_state=3407,
    use_rslora=False,
    loftq_config=None,
)

# %%
EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    if 'context' in examples.data:
        prompt = """
            You are an English-speaking oracle.
            You are given a sentence where a word has been masked with a number of question marks (?) of equal length.
            Return the masked word, do not produce any more words than the one you have to return!

            ### Instruction:
            {}

            ### Context:
            {}

            ### Response:
            {}
            """
        instructions = examples["text"]
        contexts = examples["context"]
        responses = examples["groundTruth"]
        prompts = []
        for i,j,k  in zip(instructions,contexts,responses):
            text = prompt.format(i,j,k) + EOS_TOKEN
            prompts.append(text)
    else:
        prompt = """
            You are an English-speaking oracle.
            You are given a sentence where a word has been masked with a number of question marks (?) of equal length.
            Return the masked word!

            ### Instruction:
            {}

            ### Response:
            {}
            """
        instructions = examples["text"]
        responses = examples["groundTruth"]
        prompts = []
        for i,j  in zip(instructions,responses):
            text = prompt.format(i,j) + EOS_TOKEN
            prompts.append(text)
    return { "prompt" : prompts, }

from datasets import load_dataset, Dataset
dataset = Dataset.from_pandas(train_set)    
dataset = dataset.map(formatting_prompts_func, batched = True)
# Out:
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "prompt",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        #num_train_epochs = 5,
        max_steps = 100,
        per_device_train_batch_size = 16,
        gradient_accumulation_steps = 4,
        warmup_steps = 2,
        
        learning_rate = 0.0005,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)

# Training 
trainer_stats = trainer.train()
# Out:
# Map (num_proc=2):   0%|          | 0/4000 [00:00<?, ? examples/s]
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# max_steps is given, it will override any value given in num_train_epochs
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 4,000 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 4
# \        /    Total batch size = 64 | Total steps = 100
#  "-____-"     Number of trainable parameters = 41,943,040
# /data01/atrema/miniconda3/lib/python3.12/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 03:59, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.897800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.911900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.566800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.521300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.697000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.164900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.185000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.175700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.162900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.072600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.098400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.105200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.968100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.086300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.031200</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.018900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.981200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.985500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.074800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.991700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.054400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.033800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.021400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.991600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.062800</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.115600</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.021100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.109400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.013000</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.013300</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.911800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.062900</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.039700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.006100</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.004200</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.961400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.991000</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.916700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.003200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.998300</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.976100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.959700</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.986500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.994300</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.018400</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.980300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.963100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.938600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.999700</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.967900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.938800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.990100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.970800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.065600</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.967500</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.952100</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.973800</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.960600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.947000</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.993300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.054100</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.496200</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.919300</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.864400</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.874300</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.041100</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.874700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.017300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.918400</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.900800</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.843500</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.911700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.923600</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.907900</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.846100</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.912000</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.855700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.841700</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.924700</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.892000</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.973200</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.894900</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.886000</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.840800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.908300</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.851400</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.950700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.804900</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.855200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.933400</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.826100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.917900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.905300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.879400</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.010900</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.803600</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.872300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.009900</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
model_folder
# Out:
# 'outputs/unragged_model'

# %%
model.save_pretrained_merged(model_folder, tokenizer, save_method = "merged_16bit",)
# Out:
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 1450.08 out of 2003.89 RAM for saving.
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 78.34it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Done.

# %% [markdown]
# # VLLM RESTORATION

# %%
#unless you want an OUT OF MEMORY Error
del model
del tokenizer

# %% [markdown]
# ## Load Test Data

# %%
lm_index = read_index('saved_files/test_data/test_index')
index_3 = read_index('saved_files/test_data/tfidf_index')

with open('saved_files/test_data/vectorizer', 'rb') as f:
    vectorizer_3 = pickle.load(f)
words_3 = vectorizer_3.get_feature_names_out()
with open('saved_files/test_data/matrix', 'rb') as f:
    matrix_3 = pickle.load(f)

test_set = pd.read_csv('saved_files/test_data/test_set')
lm_index = read_index('saved_files/test_data/test_index')
with open('saved_files/test_data/test_collection.pickle', 'rb') as f:
    collection = pickle.load(f)

# %% [markdown]
# ## Generation and Metrics Functions
# Generation functions for the different cases.

# %% [markdown]
# #### OLD

# %%
def gen_b(s):
    sent = s['text']
    length = sent.count('?')
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'problem', 'content' : sent}
            ]

    formatted_prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True,)
    #print(formatted_prompt)
    output = model.generate(formatted_prompt, sampling_params=BASELINE_PARAMS, use_tqdm=False,)
    temp = []
    out = output[0].outputs
    #print('Restorations: \n \n')
    for o in out:
        pred = o.text.lower()
        #print(pred)
        pred = rm_special_chars(pred)
        if pred not in temp and len(pred) == length :
            temp.append(pred)
        #print("-----------------------------\n")
    s['restorations'] = sorted(temp)
    return s

# %% [markdown]
# #### Generations

# %%
def to_gen(msg):
    formatted_prompt = tokenizer.apply_chat_template(msg, tokenize=False, add_generation_prompt=True,)
    output = model.generate(formatted_prompt, sampling_params=SAMPLING_PARAMS, use_tqdm=False)
    out = output[0].outputs
    preds = []
    for o in out:
        pair = (o.text, np.exp(o.cumulative_logprob))
        preds.append(pair)
    preds = list(set(preds))
    preds.sort(key= lambda x : x[1], reverse=True)
    return preds

def gen_0(s):
    sent = s['text']
    length = sent.count('?')
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'problem', 'content' : sent}
            ]
    s['restorations'] = to_gen(messages)
    return s
    
def gen_1(s):
    sent = s['text']
    #print("Sentence : ",sent, f"\n \n")
    length = sent.count('?')
    tmp = sent.split(' ')
    missing_word_index = tmp.index([s for s in tmp if '?' in s][0]) # get the index of the missing word
    tmp[missing_word_index] = "[MASK]"
    mask_sent = (' ').join(tmp)
    context = f'{context_header} {search_lm(mask_sent, CONTEXT_LEN)}'
    #print(context)
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'user', 'content' : sent},
                {'role' : 'context', 'content' : context}
            ]
    s['restorations'] = to_gen(messages)
    return s

def gen_2(s):
    sent = s['text']
    length = sent.count('?')
    tmp = sent.split(' ')
    missing_word_index = tmp.index([s for s in tmp if '?' in s][0]) # get the index of the missing word
    tmp[missing_word_index] = "[MASK]"
    mask_sent = (' ').join(tmp)
    
    context = search_lm(mask_sent, CONTEXT_LEN*5)
    #print(f"Initial context : {context}")
    # this is the part where the context is reduced through tf-idf
    matrix, vectorizer, words, index = tf_idify(context) # get the tf-idf matrix, the vectorizer, the set of words in it
    #tmp_sent = re.sub(r'\[\[(.*) missing characters\]\]', '?'*length, sent)
    tmp = sent.split(' ')
    missing_word_index = tmp.index([s for s in tmp if '?' in s][0]) # get the index of the missing word
    #subword = tmp[missing_word_index].replace('?', '')
    matches = []
    #for cont in context: # take the possible words from within the context
     #   cont = cont.split(" ")
     #   matches.extend([word for word in cont if len(word)==length and word not in matches]) # if word.startswith(subword)
    
    if matches == []:# no matches -> use the vanilla query
        #print("no matches")
        final_context = search_tfidf(sent, vectorizer, index, context, top_k=CONTEXT_LEN)
        #print(final_context)
    else: # take the match with highest tf-idf score
        #print(matches)
        final_context = []
        for j in range(len(matches)):
            tmp1 = tmp
            tmp1[missing_word_index] = matches[j]
            matches[j] = (' ').join(tmp1)
            fin_con = search_tfidf(matches[j], vectorizer, index, context, top_k=CONTEXT_LEN)
            #print(fin_con)
            final_context.extend(fin_con)
        final_context = list(set(final_context))[:CONTEXT_LEN]
        #print("final context:\n ", final_context)
    #print(final_context)
    context = f'{context_header} {final_context}'
    # the subset thus determined is used to generate the answer
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'user', 'content' : sent},
                {'role' : 'context', 'content' : context}
            ]
    s['restorations'] = to_gen(messages)
    return s

def gen_3(s):
    sent = s['text']
    #print("Sentence : ",sent, f"\n \n")
    length = sent.count('?')
    # this is the part where the context is found through tf-idf
    # {matrix,vectorizer,words}_3 are used
    #tmp_sent = re.sub(r'\[\[(.*) missing characters\]\]', '?'*length, sent)
    tmp = sent.split(' ')
    missing_word_index = tmp.index([s for s in tmp if '?' in s][0]) # get the index of the missing word

    #get the possible matches amongst the words present in the tf-idf matrix
    
    final_context = search_tfidf(sent, vectorizer_3, index_3, collection, top_k=CONTEXT_LEN) # FOR NO SUBWORDS
    #same_len_words = [word for word in words_3 if len(word)==length]
    #if len(same_len_words) <= CONTEXT_LEN:
    #    matches= same_len_words
    #else:
    #    matches= random.choices(same_len_words, k=CONTEXT_LEN) #cannot use all subwords otherwise it's unfeasible
    # take the match with highest tf-idf score
    #print(matches)
    #final_context = []
    #for j in range(len(matches)):
    #    tmp1 = tmp
    #    tmp1[missing_word_index] = matches[j]
    #    matches[j] = (' ').join(tmp1)
    #    fin_con = search_tfidf(matches[j], vectorizer_3, index_3, collection, top_k=CONTEXT_LEN)
        #print(fin_con)
    #    final_context.extend(fin_con)
    #final_context = list(set(final_context))[:CONTEXT_LEN]
    context = f'{context_header} {final_context}'
    #print(context)
    # the subset thus determined is used to generate the answer
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'user', 'content' : sent},
                {'role' : 'context', 'content' : context}
            ]
    s['restorations'] = to_gen(messages)
    return s

def gen_random(s):
    sent = s['text']
    #print("Sentence : ",sent, f"\n \n")
    length = sent.count('?')
    tmp = sent.split(' ')
    missing_word_index = tmp.index([s for s in tmp if '?' in s][0]) # get the index of the missing word
    context = f'{context_header} {random.sample(collection, CONTEXT_LEN)}'
    #print(context)
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'user', 'content' : sent},
                {'role' : 'context', 'content' : context}
            ]
    s['restorations'] = to_gen(messages)
    return s

# %%
def generation(test, mode):
    modes = ['noRAG', 'RAGnormal', 'RAGwithTFIDF', 'TFIDFRAG', 'base', 'random']
    mode = modes[mode]
    if mode == 'noRAG':
        test = test.progress_apply(gen_0, axis=1)
    elif mode == 'RAGnormal':
        test = test.progress_apply(gen_1, axis=1)
    elif mode == 'RAGwithTFIDF':
        test = test.progress_apply(gen_2, axis=1)
    elif mode == 'TFIDFRAG': 
        test = test.progress_apply(gen_3, axis=1)
    elif mode == 'base': 
        test = test.progress_apply(gen_b, axis=1)
    elif mode == 'random': 
        test = test.progress_apply(gen_random, axis=1)
    return test

##### MODES
# [0] : noRAG
# [1] : RAGnormal
# [2] : RAGwithTFIDF, get context from embeddings and reduce with tfidf
# [3] : TFIDFRAG
# [4] : baseline
# [5] : random

# %% [markdown]
# #### Metrics

# %%
from torchmetrics.text import CharErrorRate
CER = CharErrorRate()

def metrics(result):
    gt = result.groundTruth
    res = result.restorations
    cer = CER(res, [gt]*len(res))
    result['characterErrorRate'] = cer.item()
    if gt in res :
        result['exactMatch'] = 1
    else:
        result['exactMatch'] = 0
    return result

def topic_score(results):
    for t in results.topic.unique():
        tmp = results[results['topic'] == t]
        #print(len(tmp))
        print(f"Exact match score for {t} : {round(tmp.apply(metrics, axis=1)['exactMatch'].mean(axis=0) * 100, 2)}%")
    print(f"\n Average : {round(results.apply(metrics, axis=1)['exactMatch'].mean(axis=0)* 100, 2)}%")

def score(results):
    res = results.apply(metrics, axis=1)
    print(f"Exact match score : {round(res['exactMatch'].mean(axis=0)* 100, 2)}%")
    print(f"Average CER : {round(res['characterErrorRate'].mean(axis=0), 2)}")
    return res
    #print(f"Average CER : {round(results.apply(metrics, axis=1)['characterErrorRate'].mean(axis=0), 2)}%")

# %%
SLICES = [1, 5, 50, 200]
def ranks(result):
    gt = result.groundTruth
    res = result.restorations
    for slice in SLICES:
        choices = [x[0] for x in res[:slice] if gt in x]
        if gt in choices:
            result[f'match@{slice}'] = 1
        else:
            result[f'match@{slice}'] = 0
    return result
            
def rank_score(results):
    res = results.apply(ranks, axis=1)
    print(f"Match@1 score : {round(res['match@1'].mean(axis=0)* 100, 2)}%")
    print(f"Match@5 score : {round(res['match@5'].mean(axis=0)* 100, 2)}%")
    print(f"Match@50 score : {round(res['match@50'].mean(axis=0)* 100, 2)}%")
    print(f"Match@200 score : {round(res['match@200'].mean(axis=0)* 100, 2)}%")
    return res

# %% [markdown]
# ## Load Model

# %%
del model
del tokenizer

# %%
#model_folder= "outputs/unragged_model"
model_folder= "outputs/ragged_model"
#model_folder= "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
from vllm import LLM
from transformers import AutoTokenizer
from vllm import SamplingParams

model = LLM(model_folder)
tokenizer = AutoTokenizer.from_pretrained(model_folder) #"meta-llama/Meta-Llama-3-8B-Instruct")

# %% [markdown]
# ## Prompt and Sampling Parameters

# %%
from transformers import LogitsProcessor

class SuppressTokenProcessor(LogitsProcessor):
    def __init__(self, token_ids):
        self.token_ids = token_ids
        
    def __call__(self, input_ids, scores):
        # Set the logit of the specific token to a large negative value
        for token_id in self.token_ids:
            scores[token_id] = -float("inf")
        return scores
        
token_id_to_block = [198, 271] #tokenizer.convert_tokens_to_ids(r"life")
suppress_processor = SuppressTokenProcessor(token_id_to_block)

# %%
#MESSAGES

SAMPLING_PARAMS = SamplingParams(n=200, temperature=1, max_tokens=10, top_k = 50, logprobs=1,logits_processors=[suppress_processor]) #, best_of=9, frequency_penalty=0.0, temperature=0.2 logit_bias = {198 : 0.0}
BASELINE_PARAMS = SamplingParams(n=1, temperature=1, max_tokens=10, top_k = 50)
CONTEXT_LEN = 3

system = """
        You are an English-speaking oracle.
        You are given a sentence where a word has been masked with a number of question marks (?) of equal length.
        Return the masked word, do not produce any more words than the one you have to return!
        Use {$examples} to better understand how to produce good solutions.
        Use {$context} to guide you towards the correct answer. 
         """
examples =  """
        These are the examples that you can use to understand how to solve the task :
        
        -Example 1: INPUT= the ???? is on the table. OUTPUT=book ;
        -Example 2: INPUT= I ???? you. OUTPUT=love ;
        -Example 3: INPUT= There was a ????? cat on my porch. OUTPUT=stray
            """

context_header = "Use these documents to find the correct answer to the task : "

# %% [markdown]
# # TESTING

# %%
from tqdm import tqdm
tqdm.pandas(leave=None)

# %% [markdown]
# ## Plain LLAMA

# %%
a = res.restorations[0]
b = ['tissue']*len(a)

# %%
CER(a,b)
# Out:
# tensor(1.9103)

# %%
test_slice = test_set[:200]
if model_folder == 'meta-llama/Meta-Llama-3-8B-Instruct':
    RES_0 = generation(test_slice, 0)
    RES_1 = generation(test_slice, 1)
    RES_2 = generation(test_slice, 2)
    RES_3 = generation(test_slice, 3)
    RES_R = generation(test_slice, 5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [01:32<00:00,  2.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [01:43<00:00,  1.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [01:58<00:00,  1.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [02:11<00:00,  1.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [01:39<00:00,  2.01it/s]

# %%
modes = ["No RAG", "Transformer RAG", "Mixed RAG", "TF-IDF RAG", "Random RAG"]
results = [RES_0, RES_1, RES_2, RES_3, RES_R]
for i in range(len(results)):
    print(f"{modes[i]} results : \n")
    score(results[i])
    print("\n -------------------------------------------")
# Out:
# No RAG results :
#
# Exact match score : 17.0%
#
#  -------------------------------------------
# Transformer RAG results :
#
# Exact match score : 0.0%
#
#  -------------------------------------------
# Mixed RAG results :
#
# Exact match score : 0.0%
#
#  -------------------------------------------
# TF-IDF RAG results :
#
# Exact match score : 0.0%
#
#  -------------------------------------------
# Random RAG results :
#
# Exact match score : 0.5%
#
#  -------------------------------------------

# %% [markdown]
# ## UNRAGGED MODEL

# %%
test_slice = test_set[:1000]
if model_folder == 'outputs/unragged_model':
    RES_0 = generation(test_slice, 0)
    RES_1 = generation(test_slice, 1)
    RES_2 = generation(test_slice, 2)
    RES_3 = generation(test_slice, 3)
    RES_R = generation(test_slice, 5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:46<00:00,  3.49it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:49<00:00,  3.45it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [06:29<00:00,  2.57it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [06:55<00:00,  2.40it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:31<00:00,  3.68it/s]

# %%
modes = ["No RAG", "Transformer RAG", "Mixed RAG", "TF-IDF RAG", "Random RAG"]
results = [RES_0, RES_1, RES_2, RES_3, RES_R]
for i in range(len(results)):
    print(f"{modes[i]} results : \n")
    rank_score(results[i])
    print("\n -------------------------------------------")
# Out:
# No RAG results :
#
# Match@1 score : 40.9%
# Match@5 score : 62.4%
# Match@50 score : 73.4%
# Match@200 score : 73.6%
#
#  -------------------------------------------
# Transformer RAG results :
#
# Match@1 score : 26.5%
# Match@5 score : 46.6%
# Match@50 score : 62.0%
# Match@200 score : 62.0%
#
#  -------------------------------------------
# Mixed RAG results :
#
# Match@1 score : 26.8%
# Match@5 score : 46.9%
# Match@50 score : 63.6%
# Match@200 score : 63.9%
#
#  -------------------------------------------
# TF-IDF RAG results :
#
# Match@1 score : 26.4%
# Match@5 score : 47.4%
# Match@50 score : 62.7%
# Match@200 score : 62.8%
#
#  -------------------------------------------
# Random RAG results :
#
# Match@1 score : 28.2%
# Match@5 score : 46.9%
# Match@50 score : 62.4%
# Match@200 score : 62.4%
#
#  -------------------------------------------

# %% [markdown]
# ## RAGGED MODEL

# %%
test_slice = test_set[:1000]
if model_folder == 'outputs/ragged_model':
    RES_0 = generation(test_slice, 0)
    RES_1 = generation(test_slice, 1)
    RES_2 = generation(test_slice, 2)
    RES_3 = generation(test_slice, 3)
    RES_R = generation(test_slice, 5)

# %%
modes = ["No RAG", "Transformer RAG", "Mixed RAG", "TF-IDF RAG", "Random RAG"]
results = [RES_0, RES_1, RES_2, RES_3, RES_R]
for i in range(len(results)):
    print(f"{modes[i]} results : \n")
    rank_score(results[i])
    print("\n -------------------------------------------")

# %% [markdown]
# ## RESULTS

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# | TEST TYPE | UNRAGGED@1 | UNRAGGED@5 | UNRAGGED@50 | RAGGED@1 | RAGGED@5 | RAGGED@50 |
# |:--|---|---|---|---|---|---|
# | NO RAG | 14.7% | 34.05% | 43.28% | **29.3%** | 50.3% | 63.4% |
# | TRANSFORMER RAG | 21.5% | 40.0% | 56.3% | 20.9% | 37.15% | 49.62% |
# | MIX RAG | 21.42% | 40.08%  | 56.45% | 21.08% | 37.48% | 49.28% |
# | TFIDF RAG | **21.95%** | 40.1% | 56.3% | 20.42% | 36.78% | 48.92% |
# | RANDOM RAG | 19.8% | 38.52% | 53.52% | 19.8% | 36.25% | 47.15% |

# %%
RES_COMP = RES_0.assign(res3 = RES_3.restorations.tolist())
RES_COMP
# Out:
#                                                                                                      text  \
# 0             In the European Union a sperm bank must have a license according to the EU ?????? Directive
# 1     Carbonel is a children s book series by Barbara Sleigh first published by Puffin ????? from 1955...
# 2                                               Miopelodytes is an extinct genus of ??????????? amphibian
# 3     This ???? details Toronto FC II s league results from their inaugural season in 2015 as a member...
# 4     Designed by Alex B Mahood it is the most significant example of ??? style in southern West Virginia
# 5     The department chairs and therefore the curriculum coordinators for their area are Jennifer Dani...
# 6     The ????? African Football Association is the second Football Association in South Africa to be ...
# 7      After this ??? League of Nations formalized the UK s control of the area who renamed it Tanganyika
# 8     However despite its large black population it was also the last country in ??? western hemispher...
# 9     The CEP is comprehensive covering goods services investment and technical and ??????? quarantine...
# 10                                  San Francisco is a municipality in ??? Honduran department of Lempira
# 11                 The ???? season is JPV Marikina s 1st season in the top flight of Philippines football
# 12                       Lambert Airport Terminal 1 is a St Louis MetroLink ??????? in Edmundson Missouri
# 13                                           It is the ???? remaining extant species in the genus Glossus
# 14                          The Chief Economic ??????? is the economic advisor to the Government of India
# 15                          His last skit was an appearance in the Birdland ???? the Squirrel Nut Zippers
# 16                              Warkauden Pallo 35 is a sports ???? in Varkaus in Finland founded in 1935
# 17                                                     Currently he manages the amateur side ???? Piovera
# 18    It was mainly based at Sadler s Wells Theater London and ????? worked in co ordination with Engl...
# 19    Chapman has 4 kids and many grandchildren one of ????? has the opportunity to play for the Silve...
# 20    The ??? Defensive Team is composed of two five woman lineups a first and a second team comprisin...
# 21    ???????? Fountain also known as the Columbus Memorial is a public artwork by American sculptor L...
# 22    Pericles Lewis Professor of comparative literature at Yale University was the founding President...
# 23    Alternatively the form may derive from Caer ???? the meaning of Caer to be a fort or castle and ...
# 24                  Pfizenmaier has ??? nine singles and two doubles titles on the ITF tour in her career
# 25      That year they also ???????? Frankie Latina s Modus Operandi an arthouse film distributed by Kino
# 26    The Fincastle Resolutions was a statement ??????? on January 20 1775 by thirteen elected represe...
# 27    She became a member of the Armed Forces Art Society in 1992 a member of the Society of Women Art...
# 28     Prior to his election to the Assembly in 2014 he was an aide for ?????? State Senator Curren Price
# 29    A fixed price contract is a ???? of contract where the payment amount does not depend on resourc...
# 30                                  ???? software presented here is free but maps may need to be paid for
# 31       He is currently working on a follow up to Law and Order and a series of ?????? plays for the BBC
# 32    It was America s first post war sports car and the ????? introduced in the U S by a major automa...
# 33    Questions have also been raised about whether the IRS exceeded its authority by effectively over...
# 34    In ????????? such as England and Poland firms are clearly defined but in Latin America the situa...
# 35    ????? the Australian website s launch in March 2011 it has expanded into six editions with the a...
# 36         Moundball is a side ??????? game typically played by spectators at Major League Baseball games
# 37    Although its exact function is not defined this protein is thought to play an early and universa...
# 38                                                  In lake ???? this color is considered to fade rapidly
# 39    His case was first brought to the public prominence by ??? September 2001 Novaya Gazeta article ...
# 40    The 1952 Miami Hurricanes football team represented the University of Miami for the 1952 ???????...
# 41                                 The 15th Robert Awards ceremony was held in 1998 in ?????????? Denmark
# 42                                     Some have ???????? it as an extension of the Hofmann rearrangement
# 43    The ???????? Amateur Team Championship is a European amateur team golf championship for men orga...
# 44    What is seen is a man who is part mystic part priest and part ordinary householder performing ri...
# 45    A police ??????? was a form of municipal government used in the province of Ontario Canada begin...
# 46    The artist run nonprofit supports photographers through a community access digital lab facility ...
# 47    Andrew Cavedon is a former Australian rules footballer who played for the Fitzroy Football Club ...
# 48                                                  It was released on DVD by Peccadillo Pictures in ????
# 49                                                     It is an ????????? element in the origins of opera
# 50    The fiber was developed further as Tencel in the 1980s by Courtaulds ?????? in Coventry UK and a...
# 51    Grave robbers who are not caught usually sell ?????????? modern items anonymously and artifacts ...
# 52    It is a theme restaurant named ??? the song Cheeseburger in Paradise by American pop music singe...
# 53                                       Susan Headley was a ?????? during the late 1970s and early 1980s
# 54    The movie is a remake of the old classic Bheegi Raat starring Ashok Kumar Meena Kumari and Prade...
# 55    In 2012 it was released again from a brand new original ????? struck from a pristine negative by...
# 56         Kiahsville is an unincorporated community in southern Wayne County West ???????? United States
# 57    Many of these college religious organizations ??? affiliated with the Consortium of Christian St...
# 58    It is loosely based on the 1967 film Bonnie and Clyde ????????? some similar subplots including ...
# 59    His mother Rachel Denise was daughter of Samuel Ronald Courthope Bosanquet K C ???????? of Walsa...
# 60    A regional US bank and subsidiary of BNP Paribas Bank of the West recently completed an RBP ???????
# 61                                Phoebemima aequatoria is a species of beetle in the family ????????????
# 62    Miss Iowa USA competition is the pageant that ??????? the representative for the state of Iowa i...
# 63                                                 She became a host when ????? Air went national in 1987
# 64    Two compilations of their music have been released Fatal Charm and a remastered 2 disc CD and DV...
# 65    The women s 400 meter individual medley competition of the swimming events at the 1987 Pan Ameri...
# 66                       Studies show that 70 to 80 of youth who are incarcerated are ?????? to re offend
# 67    Willis Wharf ???? known as Clam Town USA is an unincorporated community in Northampton County Vi...
# 68    The South Atlantic Invasive Species Project is a three year project funded under ??? European Un...
# 69             The stated aim of the center is to work for justice ??????????? and peace in urban America
# 70                          He served as the Minister of Public Health under Prime Minister ?????? Jebali
# 71    On February 27 1976 the Polisario Front formally proclaimed the Sahrawi Arab Democratic Republic...
# 72    By the beginning of the fifteenth century ????? were no fewer than fourteen knights of that name...
# 73                    It was part of a series of Junior Arcade games targeted at kids ???? three to eight
# 74                   Abdallah ibn Khordadbeh was a ??????? general and governor for the Abbasid Caliphate
# 75    The Louis Comfort Tiffany Foundation was founded in 1918 by Louis Comfort Tiffany to operate his...
# 76    Daily ?????????? focuses on city specific issues in a very lucid manner which generally appeal t...
# 77                               One whose lands were incorporated into a Marquisate was superior to ????
# 78         Sometimes simple syrup corn syrup sugar or brown rice syrup is used instead of ??? maple syrup
# 79           ???? is a departure from all previous types of user assistance for Windows operating systems
# 80                                         FTSC are the ???????? North American and World IGLFA champions
# 81    The university enrolls nearly 1 500 students and offers bachelor s ??????? in more than 30 acade...
# 82                    Book One ??????? character creation alien races combat equipment and some scenarios
# 83                           Cells are Gram ???????? rods stricty aerobic non sporeforming and non motile
# 84    Conservative ideology in Taiwan constitutes the character ??? policies of the Kuomintang party a...
# 85        That same month he starred as Steve in the episode Roy Runs Away of CBS s The Betty Hutton ????
# 86    He believed that the credibility of Christianity depended on its ability to relate to Buddhism w...
# 87                              Reid has also ???? a member of the Philadelphia Eagles and Dallas Cowboys
# 88                         ?????????? elements have served with the 101st in Vietnam Iraq and Afghanistan
# 89               The company acquired Henry Robinson s Brewery in Wigan ??? Halliwell s Alexandra Brewery
# 90                                                    She was ???? in Stockholm and grew up in Gothenburg
# 91    Hill has voted with his party 97 of the time in the current session of Congress and voted in lin...
# 92                                    It belongs to the ????? Ptychagnostus in the family Ptychagnostidae
# 93                                                The genus contains three species found in ????? America
# 94    The 2002 Mongolian National Championship was the thirty fifth recorded edition of top flight foo...
# 95    The battalion is based at Marine Corps Base Camp Pendleton California and ???????? of approximat...
# 96    The title comes from William Hamilton s interest in volcanos and ??? investigations of Mount Ves...
# 97    The 1993 Cork Senior Hurling Championship was the 105th staging of the Cork Senior Hurling Champ...
# 98    Design for Verification is a set of engineering guidelines to aid designers in ensuring right fi...
# 99    This was the last Board of Supervisors ???????? in San Francisco to use the two round system of ...
# 100                       In addition Batu Kawan is home to Design Village Malaysia s largest ?????? mall
# 101   In his eleven appearances he ?????? a total of 154 runs at an average of 14 00 with a high score...
# 102   Panulirus longipes the longlegged spiny lobster is a species of spiny lobster that lives on shal...
# 103   Indoor athletics at the ???? Asian Indoor Games was held in Indoor Athletics Stadium Pattaya Tha...
# 104   A Sydney produced variety series with ???????? on music it was hosted by John Laws and produced ...
# 105   It almost completely surrounds the Brokenhead 4 Indian reserve with the ????????? of a small lak...
# 106        Giorgio Merlano is an Italian footballer who plays as a goalkeeper for ?????????? side Fassano
# 107   It was produced in 1997 through a collaboration between Carrington Productions International Cos...
# 108   The period after the elections saw increased human rights abuses corruption and ethnic tensions ...
# 109   The term engine downsizing is used when a ???????????? introduces a smaller displacement engine ...
# 110   Released as a single from Bolton s album Soul Provider it peaked at number three on the Billboar...
# 111                                    ?????? is a female given name common in English speaking countries
# 112   The First American Art Magazine is a quarterly art magazine covering contemporary ?????????? and...
# 113                                      Persicoptila ??????????? is a moth in the family Cosmopterigidae
# 114   Timothy Foecke is an American metallurgist and founder and director of the NIST Center for Autom...
# 115   Pharmacogenomics also attempts to eliminate the trial and error method of prescribing ???????? p...
# 116   The new project is intended to attract industry professionals and focus on original projects for...
# 117   Automated systems within trading houses may catch fat finger errors before they reach the market...
# 118   The crest has crossed swords for the many military establishments within Bromley s boundaries ??...
# 119                               He was part of France at FIFA World Cup 1966 but did not ???? any match
# 120   It was released as a CD single by W Minc Records in Australia on ??? Circus Records label in the...
# 121   I internal service provider Type II shared service provider Type III external service providerTy...
# 122   Its formation marked the first time since World War II that Coast Guard personnel were used exte...
# 123   The movie which used the technique of Animatronics ??? the first time in Malayalam cinema releas...
# 124                          Steve Fisk is a Washington based audio engineer record ???????? and musician
# 125                   Jodahatti is a village in Belgaum district in the ???????? state of Karnataka India
# 126           Although it never ???? it was notable for being the first aircraft designed by Horace Short
# 127   Calectasia ??????? the elegant tinsel lily is a species of flowering plants in the family Dasypo...
# 128                                      Other ????????? he held include Treasurer of Lancaster Wisconsin
# 129   It was founded by Lucas Mangope leader of the Bophuthatswana bantustan in 1997 as a successor to...
# 130   Martinez has also stated that Dollhouse is a metaphor for how people view celebrities ??? their ...
# 131   Rainbow Warrior was a ?????????? ship active in supporting a number of anti whaling anti seal hu...
# 132   Lilacine amazons ??? said to make favorable companion parrots because of their gentle affectiona...
# 133   Situated opposite Buca Bay Kioa was purchased by people from Niutao Island but the current settl...
# 134                                 Bangalaia wissmanni is a species of beetle in the ?????? Cerambycidae
# 135                                                   Cirratulidae is a family of marine polychaete ?????
# 136   The serial is written by Irfan Ahmed for Gold Bridge Media and stars Nausheen Shah Taifoor Khan ...
# 137                                                  His brother Joey is also a ???????????? darts player
# 138                           Rangers Football Club had a team in the Superleague Formula race ??? series
# 139                              Whybrow was born in Gillingham ???? and grew up in Margate and Hong Kong
# 140                          Columns about Clinton are ??? included as they would be too numerous to list
# 141                                  In April 2012 it was merged into the Ministry ??? Primary Industries
# 142             She initially rose to prominence in 1988 singing the main scores to the ???? Mystic Pizza
# 143   A by election will be held within the constituency in 2018 after the election of Jean ?????? Doo...
# 144                          CHOE FM is a French ???????? Canadian radio station located in Matane Quebec
# 145   More neutral proposed alternatives the British Isles include Britain and Ireland Atlantic Archip...
# 146   Shava is ?????????? with the Vahera tribe descendants of Mbiru who lived at Gombe Hill in presen...
# 147                              He retained this ???????? through the cabinet reshuffle of 9 August 2010
# 148   Bulmershe houses a ????? education authority learning resource unit for students with learning d...
# 149                                                In shot put his personal ?????? stands on 19 62 meters
# 150   Celest Chong is a Singaporean actress singer and former cover ????? who is currently based in Ca...
# 151   It was first released independently by hHead themselves as a cassette and then released ????? Ja...
# 152   The legislature of Tamil Nadu was bicameral until 1986 when it ??? replaced by a unicameral legi...
# 153   Laohkam is a village in Hsawlaw Township in Myitkyina ???????? in the Kachin State of north east...
# 154   Gretton is one of the few villages to retain its ?????? and whipping post which can be found on ...
# 155                                     The internal Ford codename for the unit was the T88 series ??????
# 156   The song was produced by band manager Bill Ham and recorded ??? mixed by Terry Manning Pre produ...
# 157                                     ?????????? is a commune in the Aude department in southern France
# 158   She is best known for playing the plain speaking character Kelly Evans in the ????? TV soap Pobo...
# 159   There he refereed three matches including United States v Russia on 9 November 2012 in a match t...
# 160   The Soviet Union s team featuring Lyudmila Matveyeva in fourth and two other top ??? finishers i...
# 161                                             The system was ???????? by Illinois lawyer Joseph Zingher
# 162                                            He played underage and junior club rugby with Kilkenny ???
# 163   At the 2016 Toronto International Film Festival Kati Kati won the Prize of the International Fed...
# 164   It was established in the year 1985 ??? school is run and managed by a committee called the Nain...
# 165          Hunter ?????? Hayes is an American country music singer songwriter and multi instrumentalist
# 166   The Man Behind ??? Times is a 1917 British silent crime film directed by Frank Wilson and starri...
# 167                  It ??? the chief town of the Arverni and the site of the Battle of Gergovia in 52 BC
# 168   Recovery s program is based on self control ???? confidence and increasing one s determination t...
# 169   Her most notable work in recent years was her portrayal of Bea Smith in ??? Foxtel prison drama ...
# 170   Having played 91 times for England Spacey is considered one of the greatest English footballers ...
# 171                                                   Jemma or ???? are is a town in Bauchi State Nigeria
# 172   Incorporated in 2006 the mission of the Alliance is to ?????? social change and public understan...
# 173              On 10 ???????? 2015 Conlan resigned from all his cabinet positions citing family reasons
# 174   It is a mild inhibitor of the formation of pigment in plant and animal tissues ??? is used in fo...
# 175   The same region saw 13 La ????? who won in the opening round defeat 4 Kansas State and 12 Missis...
# 176                           It Grows on You was ????????? for the 1993 Locus Award for Best Short Story
# 177                                         The original estate is a good example of Regency ????????????
# 178   Gene Bacque is a former professional baseball player who played in the ???????? professional lea...
# 179                                  Stelrad is a British ????? manufacturer of central heating radiators
# 180   A Dreamers Christmas is an album of Christmas music by John Zorn released in October 2011 on the...
# 181                            Josh van der Flier is an Irish rugby union player for Leinster ??? Ireland
# 182   Pang Juan was an ancient Chinese military general of the Wei state during the ??????? States period
# 183   Recipe for ???? also became one of Connick s biggest hits peaking at 32 in the UK Singles Chart ...
# 184   For the fourth ??????????? year the NECC Knights baseball team played in the NJCAA Division III ...
# 185   A surreal combination of gangster film and haunted house film which draws on Homer s Odyssey as ...
# 186                     The betting round ends when all players have ?????? called the last bet or folded
# 187                                        ??? Guidi were a Tuscan aristocratic family of the Middle Ages
# 188   ?????? acute allergic reaction amalgam has not been found to be associated with any adverse effects
# 189                                             Georgiana Klingle Holmes was an American poet and ???????
# 190   In 2017 he graduated from the Montgomery County Police ??????? and started working for Montgomer...
# 191                           Metius latior is a ??????? of ground beetle in the subfamily Pterostichinae
# 192   The company was closely associated with ???????? Company of London and Jardine Matheson Co of Ho...
# 193   A Double Shot at Love is an American reality television ?????? game show that first aired weekly...
# 194                                              To reset or prevent ????????? changes to the floor model
# 195      Jan Dara is a 2012 Thai film that is based on a novel by Pramool Unhathoop ??? Story of Jan Dara
# 196   Trophonella scotiana is a species of sea snail a marine gastropod mollusk in the family Muricida...
# 197   The members of the Committee are appointed by their respective chamber for a term of 4 years unl...
# 198   It is located near the ???? of the Great Rift Valley just to the southeast of the village of Che...
# 199   According to this ??? helping the enemy state can be in the form of communicating a sketch plan ...
# 200                                            ???? lots of tourists come here locally or internationally
# 201                         The concept is also known as password chaos or more broadly as ???????? chaos
# 202     Maurice was previously on ????? at Kansas University under head coach Charlie Weis from 2012 2014
# 203   Headquartered in Edmonton Alberta AIMCo manages the assets of a ??????? set of public sector pen...
# 204                       The Watson family went on to ????? a number of houses in the Green Springs area
# 205   They were nominated for being the core buildings of Minnesota s oldest Catholic liberal arts col...
# 206   In 2008 he was awarded the Academy Gold Medal by Bangladesh Academy of Sciences for ??? contribu...
# 207   The Son s Chapel Cemetery across the street has acquired several more tracts of land to attain i...
# 208   F Tulga Ocak is a retired Turkish academic and professor of classical ??????? literature and Per...
# 209                                        France and in 2016 Cortal Consors ?????? ceased its operations
# 210   Riders of the Pony Express ???? quick exchanges to new fresh horses usually within a few minutes...
# 211   Yasser started his professional career with Wadi Degla moving on loan for half a season to ?????...
# 212   Its last rabbi Shmarya Yehuda Leib Medalia was arrested and executed for alleged disloyalty in ????
# 213                                                It is 82 9 cm high 65 4 cm wide and 7 4 to 7 8 cm ????
# 214                       Originally a visita of Dingras it was raised into an ??????????? parish in 1770
# 215         To deliberately ???? such a bet solely to protect another player s hand constitutes collusion
# 216   An enthusiastic soldier he ??? been called the last knight errant because of his devotion to the...
# 217                 ????? Maria de Tavira is a former civil parish in the municipality of Tavira Portugal
# 218   The products are used by among others the oil and gas industries marine researchers and naval ??...
# 219   She was also executive producer of the short film Trump s ??????? which won Best Screenplay by P...
# 220   Weary Blues is an album by ???????? poet Langston Hughes reciting over jazz composed and arrange...
# 221                                       The Law Society of Manitoba ???? its own admission requirements
# 222   Aminopeptidase P is a hydrolase specific for N terminal imido bonds which ??? common to several ...
# 223                                                Tristan Vautier is a ?????? professional racing driver
# 224                                    The song has charted in Austria France Netherlands and ???????????
# 225   The school was part of the Midwest Collegiate Athletic Conference from 1976 to 1987 and ??? foot...
# 226   In ???? the organization merged its annual meeting with the annual meeting of the Society of Uni...
# 227   The Main North railway line trains no longer continue to the Queensland border but Werris Creek ...
# 228                     The president of the Uitvoerend Bewind was head of state of the Batavian ????????
# 229   Peter Andrews is an Australian racehorse breeder and grazier from ?????? in the Upper Hunter Val...
# 230   A similar preparation called Friar s Balsam or Compound Benzoin Tincture contains in addition Ca...
# 231   It was built as the home of Robert Long a local Baltimore merchant and today serves as the home ...
# 232   An open door policy is a communication policy in which a manager CEO MD president or supervisor ...
# 233        In addition to this he has also won one county intermediate ???????????? medal with Newcestown
# 234              ??? race is run at a distance of one mile on the turf and offers a purse of 70 000 added
# 235                       ??? album cover is painted by Wakeman s girlfriend Italian artist Alina Bencini
# 236                 Lucy ???? is a British fashion journalist specializing in women s consumer publishing
# 237   The cantilever bridge named in honor of William Bennett Henderson ????? was constructed in 1889 ...
# 238   During his time in these promotions he ???????? in singles and tag team competition the latter w...
# 239                                                 The venue is also used ??? athletics and other events
# 240   She married Ratu Joni Madraiwiwi I in November 1886 with ???? she had six children including Adi...
# 241                   It was released on April 1 2008 and debuted at ?????? 57 on the Billboard 200 chart
# 242                 For listed buildings within Inverness ????? see List of listed buildings in Inverness
# 243                                            ??????? is a monotypic moth genus of the family Hepialidae
# 244   Blues for Lou is an album by American jazz guitarist ????? Green featuring performances recorded...
# 245   Details of the northern operations center in Greater Manchester were revealed by ??? firm who bu...
# 246   The International Architecture Awards are global awards for ??? architecture landscape architect...
# 247                                  The hotel features on historic postcards and was pictured on a ?????
# 248   Edward Hubert Linfoot was a British mathematician primarily known for his work on optics but als...
# 249   The site was then turned into a private landfill in 1969 and then a commercial ????? waste landf...
# 250                                               Part is the ?????? album by the Down South Georgia Boyz
# 251                                Overall there are 87 inductees 45 inductees were ???????? posthumously
# 252                     He is also credited for creating the modern day style of Skratch ????? Skratching
# 253             Carl s theories are based on the ???? that stress is a result of a natural human response
# 254   The men s 62 kilograms event at the 1998 Asian Games ???? place on 8 December 1998 at Thunder Do...
# 255   Given a disease or medical condition ????? is a causality chain of events from the first event t...
# 256   The 1925 26 season was Aberdeen s 21st season in the top flight of Scottish football and their ?...
# 257      Basant Kumar Biswal was a politician belonging to the Indian National Congress party ???? Odisha
# 258    Robert Brito Luciano or simply Robinho is a Brazilian footballer ??? currently plays for Mesaimeer
# 259   Hampshire High School is part of Community Unit School ???????? 300 or D300 and is the newest of...
# 260   Maytenus ?????????? is a Southern African shrub or small tree of about 2m in height and one of a...
# 261   Virtually all paper ??????? requires massive cutting replanting and re cutting of wide swaths of...
# 262   The particular subset of general S expressions applicable here is composed of atoms which are by...
# 263   Empress ??? under tow from New York City to Newport Rhode Island when her seams opened and she s...
# 264                                        The reserve ???????? a five mile hiking trail and picnic areas
# 265   The American Group Psychotherapy Association is a not for profit multi disciplinary organization...
# 266                                               The show ??? be viewed online on the Dunya News website
# 267   Gulick an employee of ??? locally important Seufert salmon canning concern included a church bui...
# 268   Released on ??? 28 2005 the album includes the Swiss number one single Gumpu as well as various ...
# 269             2 at the insistence of Lost Highway who deemed ???? the album was not commercially viable
# 270   After a few setbacks the British finally assembled enough artillery and warships to bring Fort ?...
# 271   O 23 laid down as K XXIII ??? an O 21 class submarine of the Royal Netherlands Navy that saw ser...
# 272                               Kalinga is a kingdom described in the legendary Indian ???? Mahabharata
# 273   The Episcopal Diocese of Montana is ??? diocese of the Episcopal Church in the United States of ...
# 274   Chinnanati Snehitulu is a 1971 Telugu drama film ???????? by DVS Raju on DVS Productions banner ...
# 275   On 9 July 2015 it was announced that Rob Wickham was to ?????? the next area bishop from his con...
# 276                                            Currently 100 sail numbers ???? been issued to IACC yachts
# 277                                      She was leader of the London Borough of Camden ???? 2000 to 2005
# 278   A number of historians stated that changes in areas such as social security family structure sla...
# 279   240 Squadron RAF was a Royal Air Force flying boat and seaplane squadron during World War I Worl...
# 280                                      Cosmopterix trifasciella is a moth of the Cosmopterigidae ??????
# 281   The EAPPI was founded in 2002 under the auspices of the World Council of ???????? in response to...
# 282   The park ??? donated by Charles R Hall one of the City s first developers and an initial develop...
# 283   Release of the transcriptional complex frees RNA polymerase and related transcriptional machiner...
# 284   In addition the office manages Blair House the official guesthouse of the President of the ?????...
# 285   Air Itam is a state constituency in ?????? Malaysia that has been represented in the Penang Stat...
# 286   Supremacy is a World War II board wargame published in c 1940 ??? format of the game is loosely ...
# 287                                 Glen Echo ???? is a village in St Louis County Missouri United States
# 288                                        Licensed to Schoolcraft ???????? it began broadcasting in 2003
# 289   It came into existence after James R Keene spearheaded a drive in support of racehorse ???????? ...
# 290          The competition was for men ???? four nations competed and the regatta had four boat classes
# 291   William Eugene Beauvais is a Canadian classical guitarist and composer who has performed in the ...
# 292         John Najjar was a lead designer and executive stylist at Ford Motor Company for ???? 40 years
# 293   Her work is mostly described as an exploration of ??????? reality an exploration at which she wa...
# 294   Lothaire ??? accused by the British public of having failed to provide Stokes with due process o...
# 295           He is also the founder and the ???????? of the Synthesis Center at Arizona State University
# 296                             After a loan spell ???? Dundee United he moved to Partick Thistle in 2018
# 297   He won another silver medal along with teammates Bruce ????????? and Barry Wynks in the Open par...
# 298                            His contribution to the Kannada Literature world is undisputed ???????????
# 299   It was originally published on March 15 1788 in The New York Packet under the pseudonym Publius ...
# 300   Carbon stains are a skin condition characterized by a discoloration of the skin from embedded ca...
# 301   And he has participated in ?????????? and leading scores of similar campaigns over his 40 years ...
# 302   Memorial Pegasus at Ranville in Lower Normandy is a museum and memorial to the 6th Airborne ????...
# 303                                            In some ??? Welsh texts Eliwlod is a nephew of King Arthur
# 304                                      At the Caleta Hotel Sir Herbert ????? Road overlooks Catalan Bay
# 305             He was suspended for 12 games in 1928 ??? 19 games the following season both for striking
# 306   The Highland Brigade is a historical unit of the British Army which has ???? formed and reformed...
# 307                New Hanover High School is a high school located in downtown ?????????? North Carolina
# 308   In 2007 Universal Express collapsed as a result of CEO Richard Altomare issuing billions of ????...
# 309   At other times it means to serve ??? tables and still others refers to the distribution of finan...
# 310                       The Ballad Book is ??? seventh studio album of saxophone player Michael Brecker
# 311   It has the primary responsibility of establishing and ??????????? secure military communications...
# 312                                              There ???? no Princes of Germany only princes of Prussia
# 313   William Ian McKenzie is a Canadian retired professional ice hockey goaltender who played for the...
# 314   In 1931 the name of Center Market was transferred over to the Northern Liberty Market located a ...
# 315                                         Addagal is a ??????? in the southern state of Karnataka India
# 316   Entering service in 1942 the minesweeper took ???? in the Battle of the Atlantic and the invasio...
# 317                                 The release of their independent debut EP ???????? The World Is Yours
# 318              Port le Grand is a commune in the Somme department in Hauts de France in ???????? France
# 319   In 1993 he competed in one round of the British Touring Car Championship at Snetterton ???? a Fo...
# 320   Initially the series was to replace ?????? Guy after its cancelation but it was revived after th...
# 321                                         KCNIP4 a protein that in humans is encoded by the KCNIP4 ????
# 322   Wu was a concubine of ??????? Taizong after his death she married his successor and 9th son Empe...
# 323   David ?????? is a Canadian politician who was elected to in the Yukon Legislative Assembly in th...
# 324   He also served as the chairman of the Presidential Inaugural Committee and was senior adviser to...
# 325                              AM sister station KABC s talk format is heard on the KLOS ??? subchannel
# 326                                              The ???? saw heavy combat during the Battle of the Bzura
# 327                        The chemical is notable for ?????? a very strong unpleasant smell that lingers
# 328   As a Masters long distance runner Stotsenberg won ??????? medals in the World Masters Athletics ...
# 329                    The company s solutions are available in ???? on premises and cloud based versions
# 330   Mr Ceballos has worked ??? Vice President Al Gore Transportation Secretary Rod Slater and Commer...
# 331   He appeared in several cult television series including ??? Avengers The Saint The Champions and...
# 332                    Tuck is best known as the first female skipper to win a round ??? world yacht race
# 333   PfB acquired land for the preserve from the Coco Cola Company who purchased land in Belize in 19...
# 334   They are ??????????? by project based learning expeditions where students engage in interdiscipl...
# 335                             Her personal best throw is 60 68 meters achieved in ????? 2008 in Chengdu
# 336   St Kilda who had a shortage of quality ruckman especially following the departure of Trent Knobe...
# 337   In 2009 Fairbrother left New Zealand for Australia signing for the Western ????? on a two year c...
# 338   The film stars Victoria Abril as a Barcelonian divorcee ?????? up in a mystery regarding the dis...
# 339              On January 28 2008 the station modified its on air ???????? to reflect the new ownership
# 340   In 1992 she became a junior minister in the government of Resistencia and in 1996 she moved to ?...
# 341   Despite the fact that since the fall of the Kingdom of Thessalonica in 1224 Bodonitsa ??? a vass...
# 342                              ???? is an expert in intellectual property law and the law in cyberspace
# 343                          Gurban was ???? declared Shah of Shirvan after downfall of Mehrab of Shirvan
# 344   It is possible to drive or walk across a large sandy strand to the island by following ??? arrow...
# 345                                           The peasant army known as Black Eagle ??????? 50 000 rebels
# 346   ????? daughter Lorelai Gilmore and their granddaughter Rory Gilmore serve as maid of honor and b...
# 347   He had the opportunity to kick a goal in his ????? AFL game after taking a contested mark in fro...
# 348                                              Jaame Masjid is a mosque in ????????? Lancashire England
# 349   The median portion of the wall of ??? forebrain consists of a thin lamina the lamina terminalis ...
# 350                                         The town roads are narrow un ?????? and without street lights
# 351                   Having no classical ?????????? she sang the simple songs she had learned as a chlld
# 352            It was the successor to the eastern branch of the Northwest ??????????? Conservative Party
# 353   Kim Beom soo is a ????? Korean billionaire businessman the chairman of Daum Kakao a South Korean...
# 354       Jeppe Sebastian Kofod is a Danish politician and Member of the European ?????????? from Denmark
# 355   Gary Steel is a former Australian rules footballer who played with Footscray in the ????????? Fo...
# 356   Moreover SS501 shot a sensational 20 minute ??????????? style music video that brings the songs ...
# 357   A majority of the Survey s members were civilians in positions of influence on ??? various commi...
# 358     Century ???? is the third album by Die Kreuzen released in July 1988 through Touch and Go Records
# 359                                           ???? of the film was filmed by Mick using a handheld camera
# 360   The congregation was suppressed by Bishop Burke in 2003 before his departure to ???? the Roman C...
# 361              Anomie Bonhomie is the ?????? album by the British group Scritti Politti release in 1999
# 362   It was founded in the 1940s on the site of a former farm known as Supio s farm offering new ????...
# 363                                                    It is situated about two kilometers ???? Nagercoil
# 364                 All the Joy in the World is Jump5 s first Christmas ????? released on October 22 2002
# 365                    In Speak Out people can ????? in editorials dealing with local and national issues
# 366                                           Six teams currently participate in the Munster ????????????
# 367   She won a bronze medal at the World Allround Speed Skating Championships for Women in 1951 ?????...
# 368   Harry Deal and the Galaxies is a rock and roll band formed in ???????????? North Carolina United...
# 369                                   There is free general public access to ??? gardens on Temple Square
# 370   It features tools for ?????????? and debugging code for MS DOS OS 2 Windows Linux operating syst...
# 371   The Christmas Oratorio is in six parts each part being ???????? for performance on one of the ma...
# 372   In 2003 he co founded SCOTUSblog the most widely read blog covering the Supreme Court and remain...
# 373   Gohlke was one of ten photographers selected to be part of New Topographics Photographs of a Man...
# 374                           Horlaville is a French retired amateur and ???????????? football midfielder
# 375   It is the lead single from Far East Movement s third studio album Free Wired ??? production was ...
# 376                    The class ??? selected as one of the Olympic classes for the Olympics in 1920 1928
# 377                              There are three ???? organizations that govern judo in the United States
# 378   On this railway cattle were far more important than passengers so the directors ????? looking fo...
# 379   Unlike the German Gymnasium which spans grades 5 to 13 the Wirtschaftsgymnasium has only the top...
# 380                                               Lynne is also known for her distinctive ????????? voice
# 381   Created on 13 November 1939 ????????? the outbreak of the Second World War it assumed control of...
# 382                                 At club level Dolan is a two time Leinster ????????? with St Rynagh s
# 383            He committed suicide on New Year s Day 49 ??? same day that Claudius and Agrippina married
# 384               He being the grandson of the Late Shahir Sable ???????? director from Maharashtra India
# 385   From 2002 to 2009 TMG participated in Formula 1 under the team name Panasonic ?????? Racing star...
# 386   It has particular applications in retail where merchants wish to identify the best combination o...
# 387   The ??????? made their Paralympic debut in Atlanta United States and were represented by 2 male ...
# 388                              Tabernaemontana calcarea is a species of plant in the Apocynaceae ??????
# 389                He was ????????? by 25 votes in the November 2006 election and reelected again in 2010
# 390                                       In 2006 it ranked 46th on Newsweek s Top 1000 ???? Schools list
# 391   The ?????? Moselle Memorial is a museum dedicated to World War II in the Alsace Moselle region w...
# 392   He has also worked for the Tribune Company as Senior Vice President Finance and ?????????????? a...
# 393                                                 Korean Socialist ????? was a socialist party of Korea
# 394   Johnny s in the ???????? is a children s novel by the author Louis Sachar the author of the Nati...
# 395   View of the World has been parodied by Ted Rall ???????? Pictures The New Yorker The Economist a...
# 396                                   It is an activity of the European standardization organization ????
# 397                                  The following is a timeline of the history of the ???? of Homs Syria
# 398                         Rocche the communal territory is included in the Sirente Velino Regional ????
# 399   The film was chosen as India s official ????? to the Oscars to be considered for nomination in t...
# 400   Hypsodont is a pattern of dentition with high crowned ????? and enamel extending past the gum li...
# 401   The TCSG serves the people and the state by creating a ?????? of technical education whose purpo...
# 402                            The stories originally appeared in ????? Asimov s Science Fiction Magazine
# 403   The tags and notes on population status are also from Bird Checklists of the World the latter re...
# 404   He was drafted by the Gold Coast Football Club with their third selection and thirty fourth over...
# 405   Muhammad Al Hafiz ?????? is a Malaysian professional footballer who plays as a goalkeeper for Pe...
# 406                                            The Jhelum Express is a ????? train on the Indian Railways
# 407                                 Gulf Ohio maintains its corporate headquarters in ????????? Tennessee
# 408   He is best known as a member and one of ??? main vocalists of the South Korean Chinese boy group...
# 409   Kid was the first hip hop artist to ??????? a product through his official sponsorship with Kang...
# 410               It is ??????? at the southern intersection of Maryland Route 413 and Maryland Route 667
# 411   Colors on the Line and spectral colors are the only ones that are fully saturated in the sense t...
# 412   PAIX one of the earliest Internet ???????? points used a DELNI as its interconnection infrastruc...
# 413                   The lyrics describe a sinner ?????????? to hide from divine justice on Judgment Day
# 414   The immunosuppressant drug ciclosporin was originally isolated from Tolypocladium ???????? and h...
# 415   The Mughal Road from Shopian circles around ??? origin of the Poonch River and runs along its banks
# 416   ?????? 2012 Malaysia Cup Khairul was loaned to the Negeri Sembilan and he scored 2 goals in 8 ap...
# 417                       Her husband wants to try his hand at detection and with his ????? style he does
# 418                                                 It impacted ????? in the United States on May 24 2011
# 419   This implies that the Federal Government does not possess all possible powers because most of th...
# 420                                      In no case does a state route ?????? mirror a U S Highway number
# 421   Led by head coach Mark ????????? the Rampage played their home games at the Northwest Georgia Tr...
# 422   Transgender history dates ???? to the first recorded instances of transgender individuals in anc...
# 423   Leigh has lived in the Nottinghamshire borough of Gedling for ??? his life and regularly travels...
# 424             Jackson retired from coaching in 2011 and joined the Knicks as an executive in ????? 2014
# 425   The X Files team would ???? again face a malevolent AI in the William Gibson penned fifth season...
# 426   Under Hawaii state law the Director of the Hawaii ?????????? of Health who is appointed by the G...
# 427                                                   Netperf ??? originally developed at Hewlett Packard
# 428   It was released as a double a ???? with Charlotte a song which would later be re released as a s...
# 429   In a 2005 study of 2800 bottles tasted at the ???? Spectator blind tasting facilities in Napa Ca...
# 430                                                  He ??? a double hander on both forehand and backhand
# 431       It also had a smaller and thinner ???? spar aluminum frame which provided the rigidity decrease
# 432                                        He ?????? for both the Croatian and Yugoslavian national teams
# 433   It was inspired by three Tucson Arizona murders committed by Charles Schmid which were ???????? ...
# 434     Cowichan Malahat was a provincial electoral district in the ???????? province of British Columbia
# 435   Kevin Pritchard is a British former boxer who was British ????? featherweight champion between 1...
# 436                                           Rising Sun is a town in ????? County Maryland United States
# 437                                                 It is jointly owned by the company and the ??????????
# 438   That is either the carbonyl or the alcohols or both could be part of the molecule whose ????????...
# ...
# 3852  [(the, 0.9020721521875993), (the\n\n, 0.03438535282528352), (its, 0.01892037567178586), (the\n, ...
# 3853  [(cambuur, 0.09628158675590275), (herenveen, 0.06348954466546508), (club, 0.04697628381485807), ...
# 3854  [(german\n\n, 0.40161437514360465), (the\n\n, 0.13923195135735425), (the, 0.0878693683530917), (...
# 3855  [(stjohns\n, 0.0043669082812648535), (the\n\n, 0.003598311916329425), (village\n\n, 0.0022001665...
# 3856  [(the\n\n, 0.6114186611687067), (town, 0.11384706135339626), (for\n\n, 0.06524397219998565), (th...
# 3857  [(the\n, 0.8172308508085293), (both\n, 0.030542895291515763), (both, 0.027231869230816885), (it\...
# 3858  [(they\n\n, 0.20499387702742644), (that\n, 0.1783125319666387), (they, 0.0471947660881385), (the...
# 3859  [(country, 0.8973672370248357), (country\n, 0.02374380950363497), (state, 0.014856893591126795),...
# 3860  [(the\n\n, 0.3724510252109173), (it, 0.242709171110117), (they, 0.059529835912109946), (it\n\n, ...
# 3861  [(the, 0.3773960537110942), (them, 0.134446002804968), (her, 0.10346100054067632), (and\n, 0.066...
# 3862  [(station, 0.319167888785008), (museum, 0.0712795530785226), (division, 0.06522137743443109), (s...
# 3863  [(edge, 0.23914187699919554), (hedgehow, 0.07052607900494054), (hewitt, 0.05324233724916276), (r...
# 3864  [(football, 0.37079028575209505), (australian, 0.1883700002068055), (the, 0.10401915239764051), ...
# 3865  [(expert, 0.7023586640808349), (adviser, 0.04444062027411516), (experts, 0.03970723644640063), (...
# 3866  [(association, 0.24757724090435698), (nonpartisan, 0.22757309512925034), (organization, 0.073101...
# 3867  [(states, 0.9165965267527663), (texas, 0.021018310054855615), (States, 0.019066056168866162), (u...
# 3868  [(moved, 0.252983463338136), (migrated, 0.18588962886782298), (brought, 0.04183438560145842), (a...
# 3869  [(film, 0.5543196669735752), (filmmaker, 0.09250632871032109), (actor, 0.07362751090113166), (ac...
# 3870  [(laid, 0.5095465548738434), (hatched, 0.2763262094774283), (hatch, 0.0643389095797158), (hatchi...
# 3871  [(the, 0.46683684581536505), (his, 0.08262402352321367), (youngest, 0.054782154881104446), (son,...
# 3872  [(it\n, 0.19535184508995562), (this\n, 0.13284166513482737), (which\n, 0.12801606974325752), (th...
# 3873  [(functions, 0.41203467822293877), (the\n, 0.16441073718156596), (those\n, 0.12996904641343682),...
# 3874  [(other\n\n, 0.6337653008398908), (other, 0.12757740214237714), (other\n, 0.11187535562747869), ...
# 3875  [(the\n\n, 0.4070377849791964), (west, 0.14893631720721245), (west\n\n, 0.07725330151348819), (t...
# 3876  [(2016, 0.25758369380382595), (2006, 0.1289229318804104), (1996, 0.09347621515161705), (the, 0.0...
# 3877  [(the\n\n, 0.7055825030876037), (the\n, 0.16072224022420947), (its\n, 0.04914907229612031), (its...
# 3878  [(the\n\n, 0.8240461445443438), (the, 0.12983365328572674), (the\n\n<|start_header_id|><|start_h...
# 3879  [(and\n, 0.2183166792667876), (the, 0.21525931329765), (and, 0.05739135262895365), (ship, 0.0439...
# 3880  [(cup, 0.3323345483768261), (champions\n\n, 0.1904020694213698), (championship, 0.14665619808873...
# 3881  [(the, 0.4264934956292683), (her, 0.22877464011972917), (and, 0.07459592790629817), (but, 0.0252...
# 3882  [(the, 0.9206406908389784), (the\n, 0.051615881519510444), (its, 0.0027141957819002242), (broadb...
# 3883  [(man, 0.7834515167197351), (the, 0.0743330751907072), (man\n\n, 0.04352769932590945), (of, 0.01...
# 3884  [(this, 0.8866355646063314), (this\n, 0.034162359979828236), (there, 0.02110024140566563), (the,...
# 3885  [(forms\n, 0.10287256430561809), (called\n, 0.08379775659839785), (contains, 0.08237556862188289...
# 3886  [(sectors, 0.4228546160027071), (fields, 0.28329968351852325), (fields\n\n, 0.048351276672600314...
# 3887  [(the, 0.463246260765662), (the\n, 0.21687620254812162), (the\n\n, 0.14877986690341052), (it\n, ...
# 3888  [(planned, 0.270351096654455), (stations, 0.1696758691101186), (planned\n, 0.08662729374033816),...
# 3889  [(serves\n, 0.712901872577136), (serving\n, 0.048207324905893766), (serve\n, 0.01763133867216018...
# 3890  [(the\n\n, 0.37171913899997844), (the, 0.15936173346163565), (with, 0.03921964129238724), (it\n\...
# 3891  [(she\n, 0.45410031388623606), (she, 0.21670683010616895), (and\n, 0.05894184226383481), (and, 0...
# 3892  [(demonstration, 0.1278039212740252), (folkloric, 0.09756506920350834), (demonstrations, 0.09462...
# 3893  [(he, 0.18257660242646956), (she, 0.11550114877441887), (he\n, 0.0590155187632452), (the, 0.0253...
# 3894  [(the\n\n, 0.6136251246217387), (the, 0.23229208324310643), (here, 0.023137881608097172), (here\...
# 3895  [(accounting, 0.20222750345298393), (authority, 0.12371236724912879), (system, 0.121566918040148...
# 3896  [(it\n, 0.23148376249923), (the\n\n, 0.1788920895993883), (the\n, 0.09712047967993986), (and\n\n...
# 3897  [(the\n\n, 0.06333674374186013), (american, 0.06071873924629111), (former, 0.04989697068558398),...
# 3898  [(drama, 0.7524633471550105), (comedy, 0.1110153646954871), (thriller, 0.022472651686617218), (f...
# 3899  [(matches, 0.3427445551511438), (matches\n\n, 0.257648452559475), (games, 0.15577708510555843), ...
# 3900  [(the, 0.5926182895346169), (the\n, 0.048263215706995204), (it\n, 0.026450277461050588), (the\n\...
# 3901  [(the, 0.17639675437272964), (psychology, 0.05782006969997163), (human\n\n, 0.05562047618543536)...
# 3902  [(proprietor, 0.11854486819052355), (founder, 0.08080187911636154), (foundryman\n\n, 0.078488329...
# 3903  [(board, 0.07790582787601748), (school, 0.07123357106127914), (college, 0.07023555715055617), (c...
# 3904  [(kurdish, 0.10678213188065662), (kurdish\n, 0.07281088557070907), (azeri\n, 0.06034536180581459...
# 3905  [(rapid\n\n, 0.1804325755445966), (wacker\n\n, 0.08272360627502764), (wsv\n\n, 0.045276796198150...
# 3906  [(2002, 0.2851363894580554), (2010, 0.1041191818666422), (2012, 0.06706833125629626), (2009, 0.0...
# 3907  [(the, 0.8973292351345554), (the\n, 0.03053674558434603), (group, 0.0026058523140941882), (they,...
# 3908  [(the, 0.4602200483852683), (a\n\n, 0.26224037386617555), (the\n\n, 0.12855529574281957), (a, 0....
# 3909  [(and\n\n, 0.21979842097457197), (and\n, 0.20405941742964814), (louis, 0.0591657850015779), (hig...
# 3910  [(and, 0.36558936089779187), (also, 0.16053080862263366), (as\n, 0.0832713122278193), (and\n\n, ...
# 3911  [(they, 0.43547628164566415), (the, 0.20142553783192843), (them, 0.0981749995686846), (and, 0.07...
# 3912  [(book, 0.8004899942319778), (the, 0.05125595826633043), (series, 0.014795737573873336), (novel,...
# 3913  [(francis\n\n, 0.20127175337047992), (hughes, 0.04337511959190073), (hughes\n, 0.038066489735090...
# 3914  [(the, 0.673270089425314), (the\n, 0.0904763744644161), (most, 0.03807791121618602), (and\n, 0.0...
# 3915  [(the, 0.6445984769004025), (the\n, 0.26630326569914653), (the\n\n, 0.05218904054349673), (they,...
# 3916  [(and, 0.5770854513703726), (the, 0.17911915761837244), (between, 0.10491162021573368), (from, 0...
# 3917  [(the\n, 0.2527857163381441), (india, 0.09257666958356912), (thailand, 0.059936829406944114), (t...
# 3918  [(the, 0.9005807147480784), (the\n, 0.027075849930960932), (the\n\n, 0.023598591972512874), (bup...
# 3919  [(the\n\n, 0.5470012774429067), (the, 0.10937048173235306), (the\n, 0.09565508512743107), (low, ...
# 3920  [(level\n, 0.4204735456805604), (level\n\n, 0.24469653494365706), (level, 0.12113970455702239), ...
# 3921  [(done\n, 0.7979781395095861), (done, 0.1794887699365796), (made\n, 0.003430308197013509), (work...
# 3922  [(the, 0.7610309396398673), (one, 0.09243826480615801), (the\n, 0.08997499078056818), (the\n\n, ...
# 3923  [(the, 0.7693071843765635), (the\n, 0.029488875163136436), (them, 0.021439934208092606), (such, ...
# 3924  [(hard, 0.3565032842775176), (hard\n\n, 0.16491333400653782), (and\n\n, 0.10972422019200177), (t...
# 3925  [(the\n, 0.08797375854104096), (software, 0.08591602832544724), (a\n, 0.07679956886823242), (pla...
# 3926  [(school\n\n, 0.24207261281794892), (house\n\n, 0.09534718534399192), (branch\n\n, 0.08563664490...
# 3927  [(she\n, 0.3727233903433106), (has, 0.10236885192890642), (her, 0.04814606451062944), (they, 0.0...
# 3928  [(the, 0.9224485784885592), (the\n, 0.0660592898333559), (the\n\n, 0.0032561411100682155), (that...
# 3929  [(patient, 0.29320471465313575), (people, 0.16233555830214672), (one\n\n, 0.12951123524286934), ...
# 3930  [(however, 0.06835840915681665), (australia, 0.06167862640660297), (in\n\n, 0.05722278526543243)...
# 3931  [(persectella, 0.23115770286075943), (the, 0.03513394007582967), (navasota, 0.02062133117283877)...
# 3932  [(cuban, 0.12973622920281352), (juan\n\n, 0.08439299208832399), (cuban\n, 0.07806575763508834), ...
# 3933  [(view, 0.33207201932383235), (perspective, 0.2230529128568959), (third, 0.09045743432081896), (...
# 3934  [(corporation\n\n, 0.2516739665071256), (corporation, 0.13588134202261648), (corporate\n\n, 0.09...
# 3935  [(pierre, 0.09924317826990466), (gregory, 0.025036687278521798), (baker, 0.011946813184666793), ...
# 3936  [(march, 0.20530968698990604), (july, 0.12298879494902702), (january, 0.11913897044963623), (jun...
# 3937  [(the, 0.7303154558295114), (the\n, 0.14252443735080572), (and\n, 0.02457849308183383), (the\n\n...
# 3938  [(tenuisepala, 0.04476963485733739), (tenuispala, 0.011870665982242259), (tomentosaepala, 0.0109...
# 3939  [(the\n, 0.22335019720176022), (prize, 0.13453742876230262), (first, 0.09982950166887218), (5000...
# 3940  [(artist, 0.11274596996788556), (writer, 0.10087601873757542), (lecturer, 0.08206657727538094), ...
# 3941  [(her, 0.09703524038078004), (some\n, 0.07051196294334763), (parts, 0.05023940843878959), (part\...
# 3942  [(developed, 0.27343461860136886), (portrayed, 0.18869317217152776), (portrayed\n\n, 0.162281768...
# 3943  [(pseudovaricornis, 0.13817979565649946), (cerambycidae, 0.011395849007397143), (tropidion, 0.00...
# 3944  [(chefs, 0.26266136577528243), (chef, 0.13991878117324083), (television, 0.09932261985687431), (...
# 3945  [(the\n, 0.8939594961420018), (the\n\n, 0.03734354716000448), (the\n<|start_header_id|><|start_h...
# 3946  [(festivals, 0.1698413348370219), (celebrations, 0.1629276270323759), (festival, 0.0558821291139...
# 3947  [(the\n\n, 0.3437462709402784), (xcel\n\n, 0.0967572096829195), (state, 0.03218327147627061), (t...
# 3948  [(the, 0.2551768084887851), (and\n\n, 0.12436160966392883), (they, 0.07463170500791716), (cuttin...
# 3949  [(in, 0.17854717674664713), (to, 0.14972373028405037), (in\n\n, 0.10693210934279382), (the, 0.08...
# 3950  [(the, 0.8728848245949413), (the\n, 0.08061967154915825), (the\n\n, 0.01757113722751824), (at\n,...
# 3951  [(the\n\n, 0.22232794408307585), (city, 0.19836953699486426), (that, 0.09425760083567443), (ward...
# 3952  [(excluded, 0.18677195914003344), (exclusively, 0.16002537273067582), (exclusively\n, 0.04524973...
# 3953  [(tspan9, 0.6311864442935892), (tetraspanin, 0.0650478036894406), (the\n, 0.04032530812249391), ...
# 3954  [(berliner\n\n, 0.3554324599313755), (berlin\n, 0.09738131298749698), (berlinale\n\n, 0.08833608...
# 3955  [(and\n\n, 0.08180907197656555), (him, 0.06511576151089558), (but\n\n, 0.06463659254231494), (th...
# 3956  [(outdoor, 0.4403304900237176), (hard, 0.12421346012681786), (courts, 0.09876899051964198), (gra...
# 3957  [(audience, 0.12093041657211051), (screen\n\n, 0.09616883030866641), (stage, 0.08097278068668456...
# 3958  [(parliament, 0.7956635677622764), (india, 0.05364414413567201), (parliamentary, 0.0371081771801...
# 3959  [(the, 0.8146074962253568), (the\n, 0.09570040691728544), (and, 0.0038559856444446675), (his, 0....
# 3960  [(state, 0.06104356910825456), (the\n\n, 0.04010147903202938), (district, 0.03761583501578982), ...
# 3961  [(history, 0.29924374957894434), (politics, 0.15304395034984325), (anthropology, 0.0854557720995...
# 3962  [(the, 0.3621400214652159), (portions, 0.22429864980115544), (sections, 0.06290977082156889), (t...
# 3963  [(located, 0.42790528300114006), (florida\n\n, 0.19817512228627898), (florida\n, 0.1414143905475...
# 3964  [(the, 0.2968540924435616), (it, 0.2947631803054178), (they, 0.10996766341740617), (it\n, 0.0449...
# 3965  [(the\n, 0.7602849451749588), (one, 0.06803315783596706), (it\n, 0.033885076871532485), (its\n, ...
# 3966  [(developed\n\n, 0.30675858648316584), (developed\n, 0.24083860973699897), (developed, 0.1014252...
# 3967  [(london, 0.3843992971326175), (the\n, 0.1344627925461288), (the\n\n, 0.12061819510069562), (wes...
# 3968  [(sheldon\n\n, 0.2170415908339414), (amy\n\n, 0.09581379095021628), (shamy, 0.09466917953977771)...
# 3969  [(compounds, 0.8392903648197163), (chemical\n\n, 0.031043643541952107), (organic, 0.028496984753...
# 3970  [(series, 0.1394101904910648), (television\n\n, 0.12074820388815075), (program, 0.10826564246117...
# 3971  [(the, 0.15585323935587156), (fields\n\n, 0.06692646608419957), (law, 0.060650952111441024), (he...
# 3972  [(free, 0.9164723231223855), (paid, 0.008665882835594297), (call, 0.00865518577972951), (toll, 0...
# 3973  [(distilleries\n\n, 0.6427599634338215), (distillery\n\n, 0.12308529728659937), (distillery\n, 0...
# 3974  [(iran, 0.3632275939614644), (afghanistan, 0.19957302809807465), (tehran, 0.17826181996255272), ...
# 3975  [(the, 0.8367228553824488), (one, 0.025545215998765462), (its, 0.010555101562850366), (this, 0.0...
# 3976  [(the, 0.7230695510278464), (the\n\n, 0.07473584490936633), (her\n\n, 0.06746983937805313), (the...
# 3977  [(states, 0.9645018264356048), (united\n, 0.00462986496543641), (States, 0.0030789730358801717),...
# 3978  [(and, 0.18652922863674049), (the, 0.18210175236977696), (scoring, 0.17289860168842291), (there,...
# 3979  [(the, 0.6643613720597457), (this, 0.07318394671568246), (book, 0.05917796662030926), (the\n, 0....
# 3980  [(human, 0.21705168552506715), (counseling, 0.1729529069685734), (social, 0.12846947144083962), ...
# 3981  [(songs, 0.46315321201989107), (the, 0.08088320186594641), (songs\n, 0.04842803037439906), (trac...
# 3982  [(hatcher, 0.09720732961862016), (sachetanu, 0.028247158722183852), (and\n, 0.023744476334910124...
# 3983  [(pseudomelania, 0.10428246326661036), (the, 0.03547048463632988), (pseudomelaniella, 0.00573489...
# 3984  [(test, 0.301768931325757), (tools, 0.19777120726329453), (logic, 0.16262236290095533), (tools\n...
# 3985  [(the\n\n, 0.452367326198561), (the\n, 0.19011960648111567), (most, 0.114759301099209), (its, 0....
# 3986  [(theater, 0.5382781733139188), (ballet, 0.10745547956305075), (opera\n\n, 0.04180778505710049),...
# 3987  [(college, 0.4585333209077841), (american\n\n, 0.1269679401901253), (football, 0.118725587458091...
# 3988  [(the\n, 0.3496748941653825), (name\n, 0.1740114579540009), (name, 0.13707554404499991), (his\n\...
# 3989  [(grade, 0.22356467602353966), (school, 0.15619806263483774), (day, 0.15223714253123394), (jewis...
# 3990  [(planned\n, 0.3137010284720466), (founded\n, 0.11023452735401859), (funded\n, 0.054418412218614...
# 3991  [(to\n, 0.19271836024173167), (train\n, 0.08421886090797978), (rabbis, 0.06460089955415296), (ra...
# 3992  [(australia, 0.8461867414550579), (wales, 0.06645936446335535), (australia\n, 0.0326454085993687...
# 3993  [(removing\n\n, 0.34929701002562996), (downgrade, 0.05829125632872735), (upgrading, 0.0551931751...
# 3994              [(the, 0.9710881541725686), (the\n, 0.020042747324240256), (and, 0.004956224371783704)]
# 3995  [(the\n\n, 0.37778548767451825), (her\n\n, 0.05511476658579628), (the\n, 0.05212055008746593), (...
# 3996  [(woodbine, 0.4588236573013983), (woods, 0.1824566306042996), (woodard, 0.04560414313961149), (w...
# 3997  [(september\n\n, 0.12924753520028978), (october\n\n, 0.0952695816314308), (the\n\n, 0.0879128046...
# 3998  [(todd, 0.05908508747129932), (taylor, 0.05016180079086847), (ryan, 0.036629949770555184), (will...
# 3999  [(her, 0.5224880951328063), (the, 0.22291112865119067), (their, 0.026585108348355122), (it\n, 0....

# %% [markdown]
# # Data Analysis

# %%
masked_train = pd.read_csv('saved_files/train_data/train_set')
masked_test = pd.read_csv('saved_files/test_data/test_set')

# %%
train_masks = masked_train.groundTruth.tolist()
test_masks = masked_test.groundTruth.tolist()

# %%
intersection = set(train_masks).intersection(test_masks)
print(len(intersection))
# Out:
# 670

# %%
for r in [RES_0, RES_1, RES_2, RES_3, RES_R]:
    print("mean number of restorations : ", r.restorations.str.len().mean(axis=0))
# Out:
# mean number of restorations :  36.28325
# mean number of restorations :  49.69425
# mean number of restorations :  49.4495
# mean number of restorations :  49.3885
# mean number of restorations :  50.17675

# %% [markdown]
# # Output Analysis

# %%
from torchmetrics.text import CharErrorRate
preds = "there is an other sample"
target = "pingus"
cer = CharErrorRate()
cer(preds, target)
# Out:
# tensor(3.5000)

# %%
def produce(s):
    messages = [
                {'role' : 'system', 'content' : system},
                {'role' : 'examples', 'content' : examples},
                {'role' : 'problem', 'content' : s}
            ]
    formatted_prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    output = model.generate(formatted_prompt, sampling_params=SAMPLING_PARAMS, use_tqdm=False)
    #out = output[0].outputs
    #s['text'] = out[0].text
    return output

# %%
sentence = "Samuel stared at the ???????? body of his comrade, his eyes blank as cement."
#output = produce(sentence)
#outs = output[0].outputs
TEMP = 1
TOP_K = 50
TOP_P = 0.9

# %%
output = produce(sentence)
preds = []
for out in output[0].outputs:
    pair = (out.text, np.exp(out.cumulative_logprob))
    preds.append(pair)
    preds = list(set(preds))

# %%
preds
# Out:
# [('deadly', 0.0005248176041512274),
#  ('grayishfaceless', 1.7048421956564242e-07),
#  ('lifeless', 0.4259134668555747),
#  ('bleeding', 0.017377057214856363),
#  ('bleibedneye', 1.2312695885729156e-08),
#  ('coldly', 0.006265890365465455),
#  ('black', 0.0036943084194194426),
#  ('laborate', 0.00010760852485483042),
#  ('lifeless', 0.4257827773842596),
#  ('lifeless', 0.41691222045264265),
#  ('blasted', 0.00028454739051560034),
#  ('bleeding', 0.020839705233505104),
#  ('lifeless', 0.34267461537226956),
#  ('wound', 0.0007208693811802582),
#  ('bloated', 0.019919431754298663),
#  ('lifeless', 0.37317105036570625),
#  ('deadlycoldly', 0.00021136759999117538),
#  ('grayishpurple', 4.535614405373014e-05)]

# %%
output[0].outputs
# Out:
# [CompletionOutput(index=16, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-0.8535190827933548, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-5.507317473529838e-05, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.0004836343287024647, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=7, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-0.8538259750057478, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-0.00031609306461177766, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.0005295066512189806, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=8, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-0.8538259750057478, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-0.00031609306461177766, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.0005295066512189806, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=17, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-0.8538259750057478, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-0.00031609306461177766, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.0005295066512189806, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=15, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-0.8748795818537474, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-0.012394780293107033, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.009504426270723343, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=11, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-0.985718384385109, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-0.0935702919960022, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.03916771709918976, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=12, text='lifeless', token_ids=(14789, 1752, 128009), cumulative_logprob=-1.070973925292492, logprobs=[{14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {1752: Logprob(logprob=-0.2003261297941208, rank=1, decoded_token='less')}, {128009: Logprob(logprob=-0.017667420208454132, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=9, text='bleeding', token_ids=(901, 16490, 128009), cumulative_logprob=-3.870895206462592, logprobs=[{901: Logprob(logprob=-3.602980375289917, rank=5, decoded_token='ble'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {16490: Logprob(logprob=-0.26426297426223755, rank=1, decoded_token='eding')}, {128009: Logprob(logprob=-0.0036518569104373455, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=0, text='bloated', token_ids=(39245, 660, 128001), cumulative_logprob=-3.9160595536231995, logprobs=[{39245: Logprob(logprob=-2.227980375289917, rank=2, decoded_token='blo'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {660: Logprob(logprob=-0.9030166864395142, rank=2, decoded_token='ated'), 1094: Logprob(logprob=-0.5280166864395142, rank=1, decoded_token='ody')}, {128001: Logprob(logprob=-0.7850624918937683, rank=1, decoded_token='<|end_of_text|>')}], finish_reason=stop, stop_reason=128001),
#  CompletionOutput(index=18, text='bleeding', token_ids=(901, 16490, 128009), cumulative_logprob=-4.052604493685067, logprobs=[{901: Logprob(logprob=-3.602980375289917, rank=5, decoded_token='ble'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {16490: Logprob(logprob=-0.4368436932563782, rank=1, decoded_token='eding')}, {128009: Logprob(logprob=-0.012780425138771534, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=19, text='coldly', token_ids=(88172, 398, 128009), cumulative_logprob=-5.072634583339095, logprobs=[{88172: Logprob(logprob=-4.727980613708496, rank=18, decoded_token='cold'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {398: Logprob(logprob=-0.32982656359672546, rank=1, decoded_token='ly')}, {128009: Logprob(logprob=-0.014827406033873558, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=13, text='black', token_ids=(11708, 128009), cumulative_logprob=-5.600961908698082, logprobs=[{11708: Logprob(logprob=-5.352980613708496, rank=29, decoded_token='black'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {128009: Logprob(logprob=-0.24798129498958588, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=5, text='wound', token_ids=(86, 801, 128009), cumulative_logprob=-7.235052600502968, logprobs=[{86: Logprob(logprob=-4.477980613708496, rank=11, decoded_token='w'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {801: Logprob(logprob=-2.6115472316741943, rank=2, decoded_token='ound'), 13382: Logprob(logprob=-0.7365472316741943, rank=1, decoded_token='ounded')}, {128009: Logprob(logprob=-0.1455247551202774, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=10, text='deadly', token_ids=(451, 329, 398, 128009), cumulative_logprob=-7.55245977640152, logprobs=[{451: Logprob(logprob=-4.102980613708496, rank=9, decoded_token='de'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {329: Logprob(logprob=-1.6907949447631836, rank=2, decoded_token='ad'), 95304: Logprob(logprob=-0.8157949447631836, rank=1, decoded_token='ceased')}, {398: Logprob(logprob=-1.2047193050384521, rank=2, decoded_token='ly'), 128009: Logprob(logprob=-0.8297193646430969, rank=1, decoded_token='')}, {128009: Logprob(logprob=-0.5539649128913879, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=14, text='blasted', token_ids=(2067, 15386, 128001), cumulative_logprob=-8.164610743522644, logprobs=[{2067: Logprob(logprob=-5.602980613708496, rank=33, decoded_token='bl'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {15386: Logprob(logprob=-1.1685993671417236, rank=1, decoded_token='asted')}, {128001: Logprob(logprob=-1.3930307626724243, rank=1, decoded_token='<|end_of_text|>')}], finish_reason=stop, stop_reason=128001),
#  CompletionOutput(index=3, text='deadlycoldly', token_ids=(34854, 398, 88172, 398, 128009), cumulative_logprob=-8.461911760270596, logprobs=[{34854: Logprob(logprob=-2.477980375289917, rank=3, decoded_token='dead'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {398: Logprob(logprob=-0.08719857782125473, rank=1, decoded_token='ly')}, {88172: Logprob(logprob=-2.861733913421631, rank=4, decoded_token='cold'), 128009: Logprob(logprob=-1.4242340326309204, rank=1, decoded_token='')}, {398: Logprob(logprob=-2.0492992401123047, rank=2, decoded_token='ly'), 128009: Logprob(logprob=-1.7992991209030151, rank=1, decoded_token='')}, {128009: Logprob(logprob=-0.9856996536254883, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=6, text='laborate', token_ids=(75, 4422, 349, 128009), cumulative_logprob=-9.13701068609953, logprobs=[{75: Logprob(logprob=-4.477980613708496, rank=11, decoded_token='l'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {4422: Logprob(logprob=-2.7311062812805176, rank=4, decoded_token='abor'), 398: Logprob(logprob=-1.7311062812805176, rank=1, decoded_token='ly')}, {349: Logprob(logprob=-1.8610577583312988, rank=2, decoded_token='ate'), 261: Logprob(logprob=-1.3610577583312988, rank=1, decoded_token='er')}, {128009: Logprob(logprob=-0.06686603277921677, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=1, text='grayishpurple', token_ids=(11912, 819, 57607, 128009), cumulative_logprob=-10.000964909791946, logprobs=[{11912: Logprob(logprob=-3.852980375289917, rank=7, decoded_token='gray'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {819: Logprob(logprob=-0.45537176728248596, rank=1, decoded_token='ish')}, {57607: Logprob(logprob=-4.633037567138672, rank=7, decoded_token='purple'), 5902: Logprob(logprob=-0.5080374479293823, rank=1, decoded_token='white')}, {128009: Logprob(logprob=-1.0595752000808716, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=4, text='grayishfaceless', token_ids=(11912, 819, 1594, 1752, 128009), cumulative_logprob=-15.584623098373413, logprobs=[{11912: Logprob(logprob=-3.852980375289917, rank=7, decoded_token='gray'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {819: Logprob(logprob=-0.7267144322395325, rank=1, decoded_token='ish')}, {1594: Logprob(logprob=-7.311326026916504, rank=27, decoded_token='face'), 5902: Logprob(logprob=-0.5613261461257935, rank=1, decoded_token='white')}, {1752: Logprob(logprob=-3.33290433883667, rank=2, decoded_token='less'), 128009: Logprob(logprob=-0.0829043984413147, rank=1, decoded_token='')}, {128009: Logprob(logprob=-0.3606979250907898, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None),
#  CompletionOutput(index=2, text='bleibedneye', token_ids=(901, 581, 291, 3520, 68, 128009), cumulative_logprob=-18.212634921073914, logprobs=[{901: Logprob(logprob=-3.602980375289917, rank=5, decoded_token='ble'), 14789: Logprob(logprob=-0.852980375289917, rank=1, decoded_token='life')}, {581: Logprob(logprob=-5.114384651184082, rank=23, decoded_token='ib'), 16490: Logprob(logprob=-1.114384412765503, rank=1, decoded_token='eding')}, {291: Logprob(logprob=-1.5746383666992188, rank=1, decoded_token='ed')}, {3520: Logprob(logprob=-5.139236927032471, rank=25, decoded_token='ney'), 128009: Logprob(logprob=-0.7642368674278259, rank=1, decoded_token='')}, {68: Logprob(logprob=-1.4555399417877197, rank=2, decoded_token='e'), 291: Logprob(logprob=-1.3305399417877197, rank=1, decoded_token='ed')}, {128009: Logprob(logprob=-1.3258546590805054, rank=1, decoded_token='')}], finish_reason=stop, stop_reason=None)]

# %%
preds.sort(key= lambda x : x[1], reverse=True)

# %%
p = [x[0] for x in preds if 'lifeless' in x]

# %%
if 'lifeless' in p:
    print(1)
# Out:
# 1

# %%
preds
# Out:
# [('lifeless', 0.24838454175026836),
#  ('lifeless\n', 0.1694189835487959),
#  ('dead\n', 0.08346258968935745),
#  ('bloody\n', 0.06630782704125304),
#  ('bloated\n', 0.04019607728779919),
#  ('gray\n', 0.020963977036142396),
#  ('mangled\n', 0.020626719397703386),
#  ('still\n', 0.018628639097749224),
#  ('bleeding\n', 0.018201381413304716),
#  ('stiff\n', 0.018171465029939413),
#  ('white\n', 0.012805584770657366),
#  ('broken\n', 0.011269482438968253),
#  ('the\n', 0.011251886977458766),
#  ('frozen\n', 0.009453893780624775),
#  ('burned\n', 0.00696852342913257),
#  ('decaying\n', 0.005996403124781332),
#  ('rotting\n', 0.005741898230900414),
#  ('crushed\n', 0.005680046022226747),
#  ('death\n', 0.005319049721216923),
#  ('motionless', 0.004892055661451553),
#  ('lifeless\n\n', 0.004521102830132614),
#  ('terrible\n', 0.004280428674724361),
#  ('decomposing\n', 0.004014663941239302),
#  ('deceased\n', 0.00332542092961323),
#  ('corpse', 0.0028902961921068024),
#  ('ghastly\n', 0.0028029364559456747),
#  ('burnt\n', 0.0025656808854883167),
#  ('battered\n', 0.0025623620422833915),
#  ('torn\n', 0.0024388102007103798),
#  ('dead\n', 0.0024350610125789918),
#  ('brutal\n', 0.0023616754455729008),
#  ('corpses\n', 0.0020783619240661525),
#  ('emaciated\n', 0.0018637853826173514),
#  ('water\n', 0.001851380669880508),
#  ('laid\n', 0.001828343370975234),
#  ('gruesome\n', 0.0017437866907722111),
#  ('languid\n', 0.0015208186354011926),
#  ('mutilated', 0.001395161499408449),
#  ('exposed\n', 0.0011300104346593015),
#  ('withered\n', 0.00110620819564228),
#  ('motionless\n', 0.0010798955766781345),
#  ('exhausted\n', 0.0009922746022490321),
#  ('stretched\n', 0.0008062461295692477),
#  ('shattered\n', 0.0007902381761576471),
#  ('tattered\n', 0.0006957264233456217),
#  ('wet\n', 0.000604677247110538),
#  ('wasted\n', 0.00046935502294185026),
#  ('lanky\n', 0.00024884781543113425),
#  ('crisp\n', 9.186154479988723e-05),
#  ('lives\n', 5.719281430448167e-05),
#  ('splayed\n', 5.319001614731793e-05),
#  ('blended\n', 1.2370090055713377e-05),
#  ('polaroid\n', 5.046995952306577e-06),
#  ('gravesite\n\n', 8.552148515275662e-08)]

# %%
SAMPLING_PARAMS = SamplingParams(n=1, temperature=TEMP, max_tokens=10, top_k =TOP_K, top_p=TOP_P, logprobs=20,) #, best_of=9, frequency_penalty=0.0, temperature=0.2
for i in range(10):
    print(f"generation n.{i}")
    output = produce(sentence)
    outs = output[0].outputs
    out = outs[0]
    print(f'{out.text}')
    print(np.exp(out.cumulative_logprob))
    #print(out.logprobs)
    print("-"*10)
# Out:
# generation n.0
# lifeless
# 0.2788471149753743
# ----------
# generation n.1
# lifeless
# 0.2788471149753743
# ----------
# generation n.2
# dead
#
# 0.09264611688085804
# ----------
# generation n.3
# mutilated
#
# 0.007316358055034805
# ----------
# generation n.4
# lifeless
#
# 0.19164863254436829
# ----------
# generation n.5
# bloated
#
# 0.04845636856549938
# ----------
# generation n.6
# frozen
#
# 0.011065000737466316
# ----------
# generation n.7
# stiff
#
# 0.022699197158231117
# ----------
# generation n.8
# lifeless
# 0.2788471149753743
# ----------
# generation n.9
# lifeless
#
# 0.19164863254436829
# ----------

# %%
SAMPLING_PARAMS = SamplingParams(n=10, temperature=TEMP, max_tokens=10, top_k =TOP_K, top_p=TOP_P, logprobs=20,) #, best_of=9, frequency_penalty=0.0, temperature=0.2
output = produce(sentence)
outs = output[0].outputs
for out in outs:
    print(out.text)
    print(np.exp(out.cumulative_logprob))
    #print(out.logprobs)
    print("-"*10)
# Out:
# lifeless
# 0.2788471149753743
# ----------
# lifeless
#
# 0.19164863254436829
# ----------
# dead
#
# 0.09264611688085804
# ----------
# bloody
#
# 0.07050360024637689
# ----------
# bloody
#
# 0.07050360024637689
# ----------
# gray
#
# 0.023424606745035447
# ----------
# gray
#
# 0.023424606745035447
# ----------
# battered
#
# 0.0032946792106591655
# ----------
# corpses
# 0.0030395729810376404
# ----------
# tangled
#
# 0.001441004922395057
# ----------

# %%
for out in outs:
    print(out.text)
    print(np.exp(out.cumulative_logprob))
    #print(out.logprobs)
    print("-"*10)
# Out:
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# land
#
# 0.8153627968904047
# ----------
# until
#
# 0.018738851306622433
# ----------
# blood
#
# 0.0012247584127716852
# ----------

# %% [markdown]
# # Other

# %%
#RES_COMP = RES_0.assign(res1 = RES_1.restorations.tolist())
#RES_COMP

# %%
sentence = "The invasion of Iraq was justified with ???????? which later proved to be false"
d = {'text': sentence, 'groundTruth' : 'evidence'}
qualitative = pd.Series(data = d)

print(qualitative)
print("-"*10)
qual_results = gen_0(qualitative)
print(f"Simple Gen: {qual_results.restorations}")
print("-"*10)
qual_results = gen_1(qualitative)
print(f"Simple RAG: {qual_results.restorations}")
print("-"*10)
qual_results = gen_2(qualitative)
print(f"Mixed RAG: {qual_results.restorations}")
print("-"*10)
qual_results = gen_3(qualitative)
print(f"TFIDF RAG: {qual_results.restorations}")
# Out:
# text           The invasion of Iraq was justified with ???????? which later proved to be false
# groundTruth                                                                           evidence
# dtype: object
# ----------
# Simple Gen: ['evidence', 'premises']
# ----------
# Use these documents to find the correct answer to the task :  ['Arafat and Saddam Hussein and defended the placing of car bombs', 'First off they could recognise Iraqu s responsibility in initiating the', '3 He sttod firm in refusing the advice of the false prophets and insisted', 'the theological realm The false prophets understood their relatioship', 'loathed and then supported Saddam when he mounted an unprovoked attack', 'in what is now Iraq If this document were to actually turn up', 'christians verbally attack people who might otherwise have been won to', '2 Does that make the speaker a false prophet', 'simulations based around this conflict Great to go and bomb Saddam s', 'truth who would admit the possibility of errors in his reasoning All of']
# Simple RAG: ['behemoth', 'benjamin', 'building', 'case for', 'interest', 'p m kiev', 'presence', 'shephard']
# ----------
# Initial context : ['Arafat and Saddam Hussein and defended the placing of car bombs', 'First off they could recognise Iraqu s responsibility in initiating the', '3 He sttod firm in refusing the advice of the false prophets and insisted', 'the theological realm The false prophets understood their relatioship', 'loathed and then supported Saddam when he mounted an unprovoked attack', 'in what is now Iraq If this document were to actually turn up', 'christians verbally attack people who might otherwise have been won to', '2 Does that make the speaker a false prophet', 'simulations based around this conflict Great to go and bomb Saddam s', 'truth who would admit the possibility of errors in his reasoning All of', 'policy Do you want to see Saddam Hussein overturned', 'they loathed and then supported Saddam when he mounted an unprovoked', 'military operation had been a brilliant success The secret', 'Deciding what was truely a fulfillment of prophesy is very tricky', 'unintentional agents of God Their intent was to attack God s', 'backing any of the Iraqi opposition Grooming any new leadership', 'logic Faith is a given God is a absolute truth when arguing from', 'Descriptions of true and false obedience', 'promised this land through a prophet And we would need the war to be', 'a holy war There were tight constraints on behavior in those', 'Government war bunkers When the warring nations finally lie', 'that prophecy Misleading Would not that be more having to do with', 'as Christians that Christ did indeed conquer death It forshadows the', 'MR STEPHANOPOULOS Right now Saddam Hussein is not', 'marshall enough anecdotal evidence in a convincing and documented enough', 'Some Christians have taken this to mean that Pharaoh was a puppet', 'but which turned out to be totally false', 'You should be aware that the US Army was called to fight', 'Controversy for the sake of truth is a divine command', 'the spurrious arguement that the resurrection had to be true for people to be', 'Darren that implicit claim Witnessing is hardly going to work when', 'Iran Iraq war Providing technical assistance to Iran to get it s oil', 'Seems to me the evidence from Great Britain is pretty convincing that', 'to be true and it sealed the case for the doctrine', 'What I would love to see it some basis from scripture for either All war', 'and hence dangerous and were therefore targets of persecution Also since', 'clear implication of his remarks was that this was something that was', 'so demonstrably false Take a look at Great Britain sometime for a', 'would have disqualified this from being a holy war', 'being therefore a prophet he foresaw and spoke of the resurrection of Christ', 'One of you said Nixon did not start ANY secret wars', 'translating prophetic vision into a concrete when and where has always been', 'It specifically said strict fundamentalist Christians It reflects a', 'The above statement ignores reality The BD WERE provoked', 'obedience and the curse of disobedience The eternal truth is', 'word that proceeds from the mouth of the Lord Matt 4 4', 'This would seem to be precisely the denial of Divine right to command', 'Theodoret of Cyrus They agree that it is not sufficient merely to say that', 'prophesies without any explanation of the reasons for the judgement This', 'Remember the OT doctrine of 2 witnesses Perhaps the prophets']
# final context : Use these documents to find the correct answer to the task :  ['Some Christians have taken this to mean that Pharaoh was a puppet', 'word that proceeds from the mouth of the Lord Matt 4 4', '2 Does that make the speaker a false prophet', 'that prophecy Misleading Would not that be more having to do with', 'Descriptions of true and false obedience', 'but which turned out to be totally false', 'the theological realm The false prophets understood their relatioship', 'Iran Iraq war Providing technical assistance to Iran to get it s oil', 'christians verbally attack people who might otherwise have been won to', 'logic Faith is a given God is a absolute truth when arguing from']
# Mixed RAG: ['appendix', 'evidence', 'formulas', 'icrosoft', 'known as', 'leverage', 'millions', 'moreover', 'optimize', 'readings', 'rightful', 'starting', 'thereads', 'voorhaar', 'worthies']
# ----------
# Use these documents to find the correct answer to the task :  ['famous for many theorems he stated but did not prove Later', 'Q After listening to Secretary Christopher on Iraq', 'of God could not be proven That His existence can be proven by reason', 'proving whether or not something can be proven or disproven there are', 'justified or proven by the display of good works Also according', 'Adherents Various neo economic Trinitarians', 'yourself as well as everyone else Have not you ever been to a', 'a follower of Copeland for 15 years He has thousands of tapes by the', 'Sometimes they do and sometimes they do not You just have to do the', 'in what is now Iraq If this document were to actually turn up']
# TFIDF RAG: ['c nbones', 'devotion', 'evidence', 'maligned', 'moreover', 'weilding']
